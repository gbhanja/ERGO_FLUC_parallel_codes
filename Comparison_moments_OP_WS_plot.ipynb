# %% [markdown]
# #### Extracting operator method data

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_OP_all_moments.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]
third_moment = data["third_moment"]
fourth_moment = data["fourth_moment"]

# derived quantities
F_ratio = np.sqrt(variance) / Eerg
FE_ratio = np.sqrt(variance) / Eb

# %%
for i in range(len(N_arr)):
    print(
        f"N={N_arr[i]}, "
        f"τ={tau[i]:.4f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.8f}, "
        f"Ratio={ratio[i]:.8f}, "
        f"Variance={variance[i]:.8e},"
        f"Third Moment={third_moment[i]:.12e},"
        f"Fourth Moment={fourth_moment[i]:.12e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.12e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.12e}"
    )
# Out:
# N=2, τ=0.6822, Eb=1.058141, Ergotropy=1.02016837, Ratio=0.96411365, Variance=5.73601303e-01,Third Moment=2.220068229790e+00,Fourth Moment=3.443350825926e+00,Fluctuation w.r.t erg=7.423918764269e-01,Fluctuation w.r.t EB=7.157501425652e-01
# N=6, τ=0.4344, Eb=3.629995, Ergotropy=3.56907657, Ratio=0.98321793, Variance=1.81876001e+00,Third Moment=6.254885885056e+01,Fourth Moment=2.784322647269e+02,Fluctuation w.r.t erg=3.778607944167e-01,Fluctuation w.r.t EB=3.715195063238e-01
# N=10, τ=0.3478, Eb=6.304395, Ergotropy=6.23317284, Ratio=0.98870270, Variance=3.07413649e+00,Third Moment=2.952628539796e+02,Fourth Moment=2.147674359820e+03,Fluctuation w.r.t erg=2.812887760358e-01,Fluctuation w.r.t EB=2.781109727735e-01
# N=14, τ=0.2996, Eb=9.026203, Ergotropy=8.94837680, Ratio=0.99137778, Variance=4.33254985e+00,Third Moment=8.263312244082e+02,Fourth Moment=8.321215238780e+03,Fluctuation w.r.t erg=2.326095390596e-01,Fluctuation w.r.t EB=2.306039285687e-01
# N=18, τ=0.2678, Eb=11.781976, Ergotropy=11.69918954, Ratio=0.99297347, Variance=5.59260823e+00,Third Moment=1.788885442524e+03,Fourth Moment=2.302020404103e+04,Fluctuation w.r.t erg=2.021396092493e-01,Fluctuation w.r.t EB=2.007192694842e-01
# N=22, τ=0.2448, Eb=14.565646, Ergotropy=14.47879728, Ratio=0.99403745, Variance=6.85374677e+00,Third Moment=3.322057594358e+03,Fourth Moment=5.208460226067e+04,Fluctuation w.r.t erg=1.808137858039e-01,Fluctuation w.r.t EB=1.797356752468e-01
# N=26, τ=0.2272, Eb=17.375772, Ergotropy=17.28536546, Ratio=0.99479699, Variance=8.11578044e+00,Third Moment=5.572240067290e+03,Fourth Moment=1.031158674303e+05,Fluctuation w.r.t erg=1.648111457988e-01,Fluctuation w.r.t EB=1.639536313487e-01
# N=30, τ=0.2131, Eb=20.203671, Ergotropy=20.11018727, Ratio=0.99537295, Variance=9.37813152e+00,Third Moment=8.683219089340e+03,Fourth Moment=1.853386457569e+05,Fluctuation w.r.t erg=1.522797112546e-01,Fluctuation w.r.t EB=1.515751055159e-01
# N=34, τ=0.2015, Eb=23.050245, Ergotropy=22.95397475, Ratio=0.99582345, Variance=1.06408491e+01,Third Moment=1.280896967979e+04,Fourth Moment=3.099586618934e+05,Fluctuation w.r.t erg=1.421118334885e-01,Fluctuation w.r.t EB=1.415182959738e-01
# N=38, τ=0.1918, Eb=25.921318, Ergotropy=25.82234365, Ratio=0.99618172, Variance=1.19041606e+01,Third Moment=1.812005792625e+04,Fourth Moment=4.905848859466e+05,Fluctuation w.r.t erg=1.336145435661e-01,Fluctuation w.r.t EB=1.331043664237e-01
# N=42, τ=0.1834, Eb=28.797136, Ergotropy=28.69584460, Ratio=0.99648258, Variance=1.31671345e+01,Third Moment=2.474044975351e+04,Fourth Moment=7.410591603060e+05,Fluctuation w.r.t erg=1.264522681438e-01,Fluctuation w.r.t EB=1.260074827812e-01
# N=46, τ=0.1762, Eb=31.703193, Ergotropy=31.59946697, Ratio=0.99672821, Variance=1.44308332e+01,Third Moment=3.289572781748e+04,Fourth Moment=1.080973934643e+06,Fluctuation w.r.t erg=1.202170168101e-01,Fluctuation w.r.t EB=1.198236921584e-01
# N=50, τ=0.1698, Eb=34.613140, Ergotropy=34.50727152, Ratio=0.99694137, Variance=1.56941680e+01,Third Moment=4.268660202276e+04,Fourth Moment=1.526958526193e+06,Fluctuation w.r.t erg=1.148043985507e-01,Fluctuation w.r.t EB=1.144532543244e-01
# N=54, τ=0.1641, Eb=37.534061, Ergotropy=37.42618057, Ratio=0.99712580, Variance=1.69574394e+01,Third Moment=5.429732194987e+04,Fourth Moment=2.100897480462e+06,Fluctuation w.r.t erg=1.100283572123e-01,Fluctuation w.r.t EB=1.097121136018e-01
# N=58, τ=0.1590, Eb=40.469549, Ergotropy=40.35971139, Ratio=0.99728591, Variance=1.82207507e+01,Third Moment=6.791559959069e+04,Fourth Moment=2.827153970562e+06,Fluctuation w.r.t erg=1.057633213382e-01,Fluctuation w.r.t EB=1.054762705154e-01
# N=62, τ=0.1544, Eb=43.418573, Ergotropy=43.30683061, Ratio=0.99742640, Variance=1.94840400e+01,Third Moment=8.371722408324e+04,Fourth Moment=3.731735491912e+06,Fluctuation w.r.t erg=1.019255596945e-01,Fluctuation w.r.t EB=1.016632442848e-01
# N=66, τ=0.1502, Eb=46.374496, Ergotropy=46.26097186, Ratio=0.99755202, Variance=2.07471212e+01,Third Moment=1.018435067496e+05,Fourth Moment=4.840645603023e+06,Fluctuation w.r.t erg=9.846098343868e-02,Fluctuation w.r.t EB=9.821995260487e-02
# N=70, τ=0.1464, Eb=49.352556, Ergotropy=49.23717314, Ratio=0.99766206, Variance=2.20103387e+01,Third Moment=1.225762809117e+05,Fourth Moment=6.190890320099e+06,Fluctuation w.r.t erg=9.528405957569e-02,Fluctuation w.r.t EB=9.506129156663e-02
# N=74, τ=0.1429, Eb=52.339402, Ergotropy=52.22223805, Ratio=0.99776147, Variance=2.32733450e+01,Third Moment=1.460214739354e+05,Fourth Moment=7.810875900551e+06,Fluctuation w.r.t erg=9.237914181630e-02,Fluctuation w.r.t EB=9.217234796911e-02
# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_WS_all_moments.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]
third_moment = data["third_moment"]
fourth_moment = data["fourth_moment"]

# derived quantities
F_ratio = np.sqrt(variance) / Eerg
FE_ratio = np.sqrt(variance) / Eb

# %%
for i in range(len(N_arr)):
    print(
        f"N={N_arr[i]}, "
        f"τ={tau[i]:.4f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.8f}, "
        f"Ratio={ratio[i]:.8f}, "
        f"Variance={variance[i]:.8e},"
        f"Third Moment={third_moment[i]:.12e},"
        f"Fourth Moment={fourth_moment[i]:.12e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.12e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.12e}"
    )
# Out:
# N=2, τ=0.6822, Eb=1.058141, Ergotropy=1.02016837, Ratio=0.96411365, Variance=5.73601303e-01,Third Moment=2.706906966910e+00,Fourth Moment=4.987822000246e+00,Fluctuation w.r.t erg=7.423918764269e-01,Fluctuation w.r.t EB=7.157501425652e-01
# N=6, τ=0.4344, Eb=3.629995, Ergotropy=3.56907657, Ratio=0.98321793, Variance=1.81876001e+00,Third Moment=6.397410503544e+01,Fourth Moment=2.970876329600e+02,Fluctuation w.r.t erg=3.778607944167e-01,Fluctuation w.r.t EB=3.715195063238e-01
# N=10, τ=0.3478, Eb=6.304395, Ergotropy=6.23317284, Ratio=0.98870270, Variance=3.07413649e+00,Third Moment=2.975739679342e+02,Fourth Moment=2.202321496836e+03,Fluctuation w.r.t erg=2.812887760358e-01,Fluctuation w.r.t EB=2.781109727735e-01
# N=14, τ=0.2996, Eb=9.026203, Ergotropy=8.94837680, Ratio=0.99137778, Variance=4.33254985e+00,Third Moment=8.294997104797e+02,Fourth Moment=8.430372946640e+03,Fluctuation w.r.t erg=2.326095390596e-01,Fluctuation w.r.t EB=2.306039285687e-01
# N=18, τ=0.2678, Eb=11.781976, Ergotropy=11.69918954, Ratio=0.99297347, Variance=5.59260823e+00,Third Moment=1.792890238946e+03,Fourth Moment=2.320209398889e+04,Fluctuation w.r.t erg=2.021396092493e-01,Fluctuation w.r.t EB=2.007192694842e-01
# N=22, τ=0.2448, Eb=14.565646, Ergotropy=14.47879728, Ratio=0.99403745, Variance=6.85374677e+00,Third Moment=3.326881040252e+03,Fourth Moment=5.235717546538e+04,Fluctuation w.r.t erg=1.808137858038e-01,Fluctuation w.r.t EB=1.797356752468e-01
# N=26, τ=0.2272, Eb=17.375772, Ergotropy=17.28536546, Ratio=0.99479699, Variance=8.11578044e+00,Third Moment=5.577865291998e+03,Fourth Moment=1.034967834448e+05,Fluctuation w.r.t erg=1.648111457988e-01,Fluctuation w.r.t EB=1.639536313487e-01
# N=30, τ=0.2131, Eb=20.203671, Ergotropy=20.11018727, Ratio=0.99537295, Variance=9.37813152e+00,Third Moment=8.689633903944e+03,Fourth Moment=1.858454074106e+05,Fluctuation w.r.t erg=1.522797112546e-01,Fluctuation w.r.t EB=1.515751055159e-01
# N=34, τ=0.2015, Eb=23.050245, Ergotropy=22.95397475, Ratio=0.99582345, Variance=1.06408491e+01,Third Moment=1.281616146694e+04,Fourth Moment=3.106085136816e+05,Fluctuation w.r.t erg=1.421118334885e-01,Fluctuation w.r.t EB=1.415182959738e-01
# N=38, τ=0.1918, Eb=25.921318, Ergotropy=25.82234365, Ratio=0.99618172, Variance=1.19041606e+01,Third Moment=1.812801056063e+04,Fourth Moment=4.913946383302e+05,Fluctuation w.r.t erg=1.336145435661e-01,Fluctuation w.r.t EB=1.331043664237e-01
# N=42, τ=0.1834, Eb=28.797136, Ergotropy=28.69584460, Ratio=0.99648258, Variance=1.31671345e+01,Third Moment=2.474915866137e+04,Fourth Moment=7.420459343649e+05,Fluctuation w.r.t erg=1.264522681438e-01,Fluctuation w.r.t EB=1.260074827813e-01
# N=46, τ=0.1762, Eb=31.703193, Ergotropy=31.59946697, Ratio=0.99672821, Variance=1.44308332e+01,Third Moment=3.290517310165e+04,Fourth Moment=1.082153761807e+06,Fluctuation w.r.t erg=1.202170168102e-01,Fluctuation w.r.t EB=1.198236921585e-01
# N=50, τ=0.1698, Eb=34.613140, Ergotropy=34.50727152, Ratio=0.99694137, Variance=1.56941680e+01,Third Moment=4.269677967543e+04,Fourth Moment=1.528348136843e+06,Fluctuation w.r.t erg=1.148043985508e-01,Fluctuation w.r.t EB=1.144532543246e-01
# N=54, τ=0.1641, Eb=37.534061, Ergotropy=37.42618057, Ratio=0.99712580, Variance=1.69574394e+01,Third Moment=5.430822372476e+04,Fourth Moment=2.102513172890e+06,Fluctuation w.r.t erg=1.100283572125e-01,Fluctuation w.r.t EB=1.097121136020e-01
# N=58, τ=0.1590, Eb=40.469549, Ergotropy=40.35971139, Ratio=0.99728591, Variance=1.82207507e+01,Third Moment=6.792721492819e+04,Fourth Moment=2.829011643190e+06,Fluctuation w.r.t erg=1.057633213386e-01,Fluctuation w.r.t EB=1.054762705157e-01
# N=62, τ=0.1544, Eb=43.418573, Ergotropy=43.30683061, Ratio=0.99742640, Variance=1.94840400e+01,Third Moment=8.372954298489e+04,Fourth Moment=3.733850842802e+06,Fluctuation w.r.t erg=1.019255596948e-01,Fluctuation w.r.t EB=1.016632442850e-01
# N=66, τ=0.1502, Eb=46.374496, Ergotropy=46.26097186, Ratio=0.99755202, Variance=2.07471212e+01,Third Moment=1.018565235088e+05,Fourth Moment=4.843034539476e+06,Fluctuation w.r.t erg=9.846098343900e-02,Fluctuation w.r.t EB=9.821995260518e-02
# N=70, τ=0.1464, Eb=49.352556, Ergotropy=49.23717314, Ratio=0.99766206, Variance=2.20103387e+01,Third Moment=1.225899796951e+05,Fourth Moment=6.193567447403e+06,Fluctuation w.r.t erg=9.528405957606e-02,Fluctuation w.r.t EB=9.506129156699e-02
# N=74, τ=0.1429, Eb=52.339402, Ergotropy=52.22223805, Ratio=0.99776147, Variance=2.32733450e+01,Third Moment=1.460358476349e+05,Fourth Moment=7.813856494287e+06,Fluctuation w.r.t erg=9.237914181668e-02,Fluctuation w.r.t EB=9.217234796948e-02
# N=78, τ=0.1397, Eb=55.347084, Ergotropy=55.22807560, Ratio=0.99784978, Variance=2.45363433e+01,Third Moment=1.724878050712e+05,Fourth Moment=9.747399796506e+06,Fluctuation w.r.t erg=8.969020346674e-02,Fluctuation w.r.t EB=8.949734936712e-02
# N=82, τ=0.1367, Eb=58.353712, Ergotropy=58.23302660, Ratio=0.99793182, Variance=2.57989335e+01,Third Moment=2.019473130073e+05,Fourth Moment=1.201873249106e+07,Fluctuation w.r.t erg=8.722309922315e-02,Fluctuation w.r.t EB=8.704270637301e-02
# N=86, τ=0.1339, Eb=61.366724, Ergotropy=61.24443316, Ratio=0.99800722, Variance=2.70612683e+01,Third Moment=2.346576467084e+05,Fourth Moment=1.467178128625e+07,Fluctuation w.r.t erg=8.493906073595e-02,Fluctuation w.r.t EB=8.476979589705e-02
# N=90, τ=0.1313, Eb=64.394486, Ergotropy=64.27057251, Ratio=0.99807571, Variance=2.83234447e+01,Third Moment=2.709068916423e+05,Fourth Moment=1.775761271978e+07,Fluctuation w.r.t erg=8.280582088050e-02,Fluctuation w.r.t EB=8.264647837814e-02
# N=94, τ=0.1288, Eb=67.403448, Ergotropy=67.27820914, Ratio=0.99814196, Variance=2.95851250e+01,Third Moment=3.104573931581e+05,Fourth Moment=2.128351109552e+07,Fluctuation w.r.t erg=8.084669704274e-02,Fluctuation w.r.t EB=8.069648044862e-02
# N=98, τ=0.1265, Eb=70.441302, Ergotropy=70.31457043, Ratio=0.99820089, Variance=3.08467862e+01,Third Moment=3.541106601262e+05,Fourth Moment=2.535084918164e+07,Fluctuation w.r.t erg=7.898773019419e-02,Fluctuation w.r.t EB=7.884562254096e-02
# N=102, τ=0.1244, Eb=73.518698, Ergotropy=73.39022244, Ratio=0.99825247, Variance=3.21083649e+01,Third Moment=4.023146877992e+05,Fourth Moment=3.003832493020e+07,Fluctuation w.r.t erg=7.720952682108e-02,Fluctuation w.r.t EB=7.707460117297e-02
# N=106, τ=0.1223, Eb=76.545842, Ergotropy=76.41617014, Ratio=0.99830596, Variance=3.33693724e+01,Third Moment=4.538311910325e+05,Fourth Moment=3.525752627755e+07,Fluctuation w.r.t erg=7.559424808780e-02,Fluctuation w.r.t EB=7.546618868170e-02
# N=110, τ=0.1204, Eb=79.625187, Ergotropy=79.49395632, Ratio=0.99835189, Variance=3.46302912e+01,Third Moment=5.105560749098e+05,Fourth Moment=4.123484655293e+07,Fluctuation w.r.t erg=7.402764945136e-02,Fluctuation w.r.t EB=7.390564402243e-02
# N=114, τ=0.1186, Eb=82.713177, Ergotropy=82.58040912, Ratio=0.99839484, Variance=3.58908793e+01,Third Moment=5.720005214143e+05,Fourth Moment=4.796177772723e+07,Fluctuation w.r.t erg=7.254625847914e-02,Fluctuation w.r.t EB=7.242980984675e-02
# N=118, τ=0.1168, Eb=85.755931, Ergotropy=85.62207900, Ratio=0.99843915, Variance=3.71511987e+01,Third Moment=6.371979912427e+05,Fourth Moment=5.536602548124e+07,Fluctuation w.r.t erg=7.118699272312e-02,Fluctuation w.r.t EB=7.107588046400e-02
# N=122, τ=0.1152, Eb=88.873106, Ergotropy=88.73764816, Ratio=0.99847583, Variance=3.84111508e+01,Third Moment=7.089238707707e+05,Fourth Moment=6.380551814962e+07,Fluctuation w.r.t erg=6.984265576853e-02,Fluctuation w.r.t EB=6.973620359926e-02
# N=126, τ=0.1136, Eb=91.950009, Ergotropy=91.81334084, Ratio=0.99851367, Variance=3.96709154e+01,Third Moment=7.848278756151e+05,Fourth Moment=7.304996548961e+07,Fluctuation w.r.t erg=6.860098009485e-02,Fluctuation w.r.t EB=6.849901641687e-02
# N=130, τ=0.1121, Eb=95.050951, Ergotropy=94.91295642, Ratio=0.99854821, Variance=4.09303265e+01,Third Moment=8.666155185094e+05,Fourth Moment=8.334736373615e+07,Fluctuation w.r.t erg=6.740577447812e-02,Fluctuation w.r.t EB=6.730791537755e-02
# N=134, τ=0.1107, Eb=98.181878, Ergotropy=98.04240470, Ratio=0.99857944, Variance=4.21892593e+01,Third Moment=9.547614739293e+05,Fourth Moment=9.481092604594e+07,Fluctuation w.r.t erg=6.625016982615e-02,Fluctuation w.r.t EB=6.615605719197e-02
# N=138, τ=0.1093, Eb=101.276291, Ergotropy=101.13567402, Ratio=0.99861155, Variance=4.34481859e+01,Third Moment=1.047576932791e+06,Fourth Moment=1.072668684391e+08,Fluctuation w.r.t erg=6.517506171209e-02,Fluctuation w.r.t EB=6.508456927420e-02
# N=142, τ=0.1080, Eb=104.407601, Ergotropy=104.26563450, Ratio=0.99864027, Variance=4.47065446e+01,Third Moment=1.147422800281e+06,Fourth Moment=1.210800417457e+08,Fluctuation w.r.t erg=6.412750769603e-02,Fluctuation w.r.t EB=6.404031155718e-02
# N=146, τ=0.1067, Eb=107.503900, Ergotropy=107.36089033, Ratio=0.99866973, Variance=4.59650193e+01,Third Moment=1.252215933413e+06,Fourth Moment=1.360126338876e+08,Fluctuation w.r.t erg=6.314916599674e-02,Fluctuation w.r.t EB=6.306516054471e-02
# N=150, τ=0.1055, Eb=110.644751, Ergotropy=110.50044411, Ratio=0.99869576, Variance=4.72227680e+01,Third Moment=1.364831864413e+06,Fourth Moment=1.525274171392e+08,Fluctuation w.r.t erg=6.218873124470e-02,Fluctuation w.r.t EB=6.210762223627e-02
# N=154, τ=0.1044, Eb=113.837173, Ergotropy=113.69127838, Ratio=0.99871839, Variance=4.84795296e+01,Third Moment=1.486001148192e+06,Fourth Moment=1.708071175389e+08,Fluctuation w.r.t erg=6.124237840029e-02,Fluctuation w.r.t EB=6.116388955637e-02
# N=158, τ=0.1033, Eb=117.000947, Ergotropy=116.85371894, Ratio=0.99874165, Variance=4.97363490e+01,Third Moment=1.612972178635e+06,Fourth Moment=1.904998407122e+08,Fluctuation w.r.t erg=6.035238151004e-02,Fluctuation w.r.t EB=6.027643695512e-02
# N=202, τ=0.0932, Eb=151.930037, Ergotropy=151.77042968, Ratio=0.99894947, Variance=6.35427308e+01,Third Moment=3.524746376614e+06,Fourth Moment=5.393074871468e+08,Fluctuation w.r.t erg=5.252254645747e-02,Fluctuation w.r.t EB=5.246736982945e-02

# %%
E_ergo_OP = data["Eerg"]
E_var_OP = data["variance"]
E_third_OP = data["third_moment"]
E_fourth_OP = data["fourth_moment"]

E_ergo_WS = data["Eerg"]
E_var_WS = data["variance"]
E_third_WS = data["third_moment"]
E_fourth_WS = data["fourth_moment"]

erg_OP = np.array(E_ergo_OP).flatten()
var_OP = np.array(E_var_OP).flatten()
third_OP = np.array(E_third_OP).flatten()
fourth_OP = np.array(E_fourth_OP).flatten()

erg_WS = np.array(E_ergo_WS).flatten()
var_WS = np.array(E_var_WS).flatten()
third_WS = np.array(E_third_WS).flatten()
fourth_WS = np.array(E_fourth_WS).flatten()

# %%
######################################
# Plot 1: Ergotropy (1st Moment) vs N
######################################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, erg_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, erg_WS, 's--', color='red', label='WS Formalism', markersize=3)

plt.xlabel(r"$N$ (Number of spins)", fontsize=12)
plt.ylabel(r"Ergotropy ($\mathcal{E})$", fontsize=12)
plt.title(r"Ergotropy vs N", fontsize=14)
plt.legend()
plt.tight_layout()
#plt.savefig("m1.png")
plt.show()

# %%
#######################################
# Plot 2: Variance (2nd Cumulant) vs N
#######################################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, var_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, var_WS, 's--', color='red', label='WS Formalism', markersize=3)

plt.xlabel(r"$N$ (Number of spins)", fontsize=12)
plt.ylabel(r"$\mathrm{Var}(\mathcal{E})$", fontsize=12)
plt.title(r"Variance vs N", fontsize=14)
plt.legend()
plt.tight_layout()
#plt.savefig("m2.png")
plt.show()

# %%
############################
# Plot 3: Third Moment vs N
############################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, third_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, third_WS, 's--', color='red', label='WS Formalism', markersize=3)

plt.xlabel(r"$N$ (Number of spins)", fontsize=12)
plt.ylabel(r"Third Moment of $\mathcal{E}$", fontsize=12)
plt.title(r"Third Moment of $\mathcal{E}$ vs N", fontsize=14)
plt.legend()
plt.tight_layout()
#plt.savefig("m3.png")
plt.show()

# %%
#############################
# Plot 1: Fourth Moment vs N
#############################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, fourth_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, fourth_WS, 's--', color='red', label='WS Formalism', markersize=3)

plt.xlabel(r"$N$ (Number of spins)", fontsize=12)
plt.ylabel(r"Ergotropy ($\mathcal{E})$", fontsize=12)
plt.title(r"Ergotropy vs N", fontsize=14)
plt.legend()
plt.tight_layout()
#plt.savefig("m4.png")
plt.show()
