# %% [markdown]
# #### Extracting operator method data

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_OP_all_moments.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]
third_moment = data["third_moment"]

# derived quantities
F_ratio = np.sqrt(variance) / Eerg
FE_ratio = np.sqrt(variance) / Eb

# %%
for i in range(len(N_arr)):
    print(
        f"N={N_arr[i]}, "
        f"τ={tau[i]:.4f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.6f}, "
        f"Ratio={ratio[i]:.6f}, "
        f"Variance={variance[i]:.10e},"
        f"Third Moment={third_moment[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.10e}"
    )
# Out:
# N=2, τ=0.6822, Eb=1.058141, Ergotropy=1.020168, Ratio=0.964114, Variance=5.7360130333e-01,Third Moment=2.2200682298e+00,Fluctuation w.r.t erg=7.4239187643e-01,Fluctuation w.r.t EB=7.1575014257e-01
# N=6, τ=0.4344, Eb=3.629995, Ergotropy=3.569077, Ratio=0.983218, Variance=1.8187600085e+00,Third Moment=6.2548858851e+01,Fluctuation w.r.t erg=3.7786079442e-01,Fluctuation w.r.t EB=3.7151950632e-01
# N=10, τ=0.3478, Eb=6.304395, Ergotropy=6.233173, Ratio=0.988703, Variance=3.0741364854e+00,Third Moment=2.9526285398e+02,Fluctuation w.r.t erg=2.8128877604e-01,Fluctuation w.r.t EB=2.7811097277e-01
# N=14, τ=0.2996, Eb=9.026203, Ergotropy=8.948377, Ratio=0.991378, Variance=4.3325498451e+00,Third Moment=8.2633122441e+02,Fluctuation w.r.t erg=2.3260953906e-01,Fluctuation w.r.t EB=2.3060392857e-01
# N=18, τ=0.2678, Eb=11.781976, Ergotropy=11.699190, Ratio=0.992973, Variance=5.5926082320e+00,Third Moment=1.7888854425e+03,Fluctuation w.r.t erg=2.0213960925e-01,Fluctuation w.r.t EB=2.0071926948e-01
# ...

# %% [markdown]
# #### Extracting work statistics data

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_WS_all_moments.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]
third_moment = data["third_moment"]

# derived quantities
F_ratio = np.sqrt(variance) / Eerg
FE_ratio = np.sqrt(variance) / Eb

# %%
for i in range(len(N_arr)):
    print(
        f"N={N_arr[i]}, "
        f"τ={tau[i]:.4f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.6f}, "
        f"Ratio={ratio[i]:.6f}, "
        f"Variance={variance[i]:.10e},"
        f"Third Moment={third_moment[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.10e}"
    )
# Out:
# N=2, τ=0.6822, Eb=1.058141, Ergotropy=1.020168, Ratio=0.964114, Variance=5.7360130333e-01,Third Moment=2.7069069669e+00,Fluctuation w.r.t erg=7.4239187643e-01,Fluctuation w.r.t EB=7.1575014257e-01
# N=6, τ=0.4344, Eb=3.629995, Ergotropy=3.569077, Ratio=0.983218, Variance=1.8187600085e+00,Third Moment=6.3974105035e+01,Fluctuation w.r.t erg=3.7786079442e-01,Fluctuation w.r.t EB=3.7151950632e-01
# N=10, τ=0.3478, Eb=6.304395, Ergotropy=6.233173, Ratio=0.988703, Variance=3.0741364854e+00,Third Moment=2.9757396793e+02,Fluctuation w.r.t erg=2.8128877604e-01,Fluctuation w.r.t EB=2.7811097277e-01
# N=14, τ=0.2996, Eb=9.026203, Ergotropy=8.948377, Ratio=0.991378, Variance=4.3325498451e+00,Third Moment=8.2949971048e+02,Fluctuation w.r.t erg=2.3260953906e-01,Fluctuation w.r.t EB=2.3060392857e-01
# N=18, τ=0.2678, Eb=11.781976, Ergotropy=11.699190, Ratio=0.992973, Variance=5.5926082320e+00,Third Moment=1.7928902389e+03,Fluctuation w.r.t erg=2.0213960925e-01,Fluctuation w.r.t EB=2.0071926948e-01
# ...

# %%
E_ergo_OP = data["Eerg"]
E_var_OP = data["variance"]
E_third_OP = data["third_moment"]

E_ergo_WS = data["Eerg"]
E_var_WS = data["variance"]
E_third_WS = data["third_moment"]

erg_OP = np.array(E_ergo_OP).flatten()
var_OP = np.array(E_var_OP).flatten()
third_OP = np.array(E_third_OP).flatten()

erg_WS = np.array(E_ergo_WS).flatten()
var_WS = np.array(E_var_WS).flatten()
third_WS = np.array(E_third_WS).flatten()

# %%
#########################################################
# Plot 1: Ergotropy (1st Moment) vs N
#########################################################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, erg_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, erg_WS, 's--', color='red', label='WS Formalism', markersize=6)

plt.xlabel(r"$N$ (Number of spins)", fontsize=14)
plt.ylabel(r"Ergotropy ($\mathcal{E})$", fontsize=14)
plt.title(r"Ergotropy vs N", fontsize=16)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
#########################################################
# Plot 2: Variance (2nd Moment) vs N
#########################################################
plt.figure(figsize=(8, 5))
plt.plot(N_arr, var_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, var_WS, 's--', color='red', label='WS Formalism', markersize=6)

plt.xlabel(r"$N$ (Number of spins)", fontsize=14)
plt.ylabel(r"$\mathrm{Var}(\mathcal{E})$", fontsize=14)
plt.title(r"Variance vs N", fontsize=16)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
#########################################################
# Plot 3: Third Moment vs N
#########################################################
plt.figure(figsize=(16, 9))
plt.plot(N_arr, third_OP, 'o-', color='blue', label='OP Formalism', markersize=6)
plt.plot(N_arr, third_WS, 's--', color='red', label='WS Formalism', markersize=6)

plt.xlabel(r"$N$ (Number of spins)", fontsize=14)
plt.ylabel(r"Third Moment of $\mathcal{E}$", fontsize=14)
plt.title(r"Third Moment of $\mathcal{E}$ vs N", fontsize=16)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import re
from matplotlib.ticker import MaxNLocator, AutoMinorLocator

# (Paste your operator_text and ws_text raw data blocks here like before)

def parse_third_moment(text):
    N_list, third_list = [], []
    for line in text.strip().split('\n'):
        if not line.strip(): continue
        try:
            N = int(re.search(r'N=(\d+)', line).group(1))
            third = float(re.search(r'Third Moment=([0-9.eE+-]+)', line).group(1))
            N_list.append(N)
            third_list.append(third)
        except AttributeError:
            pass # Skips malformed lines safely
    return np.array(N_list), np.array(third_list)

# Parse the text blocks
N_full, OP_full = parse_third_moment(operator_text)
_, WS_full = parse_third_moment(ws_text)

# Slicing [1:51:4] exactly as requested
N_sub = N_full[1:51:6]
OP_sub = OP_full[1:51:6]
WS_sub = WS_full[1:51:6]

fig, ax = plt.subplots(figsize=(16, 10))

# Plot the lines
ax.plot(N_sub, OP_sub, 'o-', color='blue', label='OP Formalism', markersize=6)
ax.plot(N_sub, WS_sub, 's--', color='red', label='WS Formalism', markersize=6)

# for x, y_op, y_ws in zip(N_sub, OP_sub, WS_sub):
#     # OP values slightly ABOVE the point, shifted LEFT
#     ax.annotate(f'{y_op:.4e}', 
#                 (x, y_op), 
#                 # textcoords="offset points", 
#                 xytext=(-10, 15), 
#                 ha='right', 
#                 va='bottom',
#                 color='blue', 
#                 fontsize=11, 
#                 rotation=30)
                
#     # WS values slightly BELOW the point, shifted RIGHT
#     ax.annotate(f'{y_ws:.4e}', 
#                 (x, y_ws), 
#                 # textcoords="offset points", 
#                 xytext=(10, -20), 
#                 ha='left', 
#                 va='top',
#                 color='red', 
#                 fontsize=11, 
#                 rotation=30)

ax.set_xlabel(r"$N$ (Number of spins)", fontsize=14)
ax.set_ylabel(r"Third Moment of $\mathcal{E}$", fontsize=14)
ax.set_title(r"Third Moment of $\mathcal{E}$ vs $N$", fontsize=16)
ax.legend(fontsize=12)

# -------------------------------------------------------------
# TICK LOCATORS FOR PRECISE Y-AXIS DIVISIONS
# -------------------------------------------------------------
# Force up to 20 major tick marks on the Y-axis
ax.yaxis.set_major_locator(MaxNLocator(nbins=10))

# Add 5 minor tick intervals between every major Y-axis tick
ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# You can do the same for the X-axis for better alignment
ax.xaxis.set_major_locator(MaxNLocator(nbins=10))


# Add extra space at the top and bottom so rotated annotations don't get cut off
y_min, y_max = ax.get_ylim()
ax.set_ylim(y_min - (y_max * 0.1), y_max * 1.15)

plt.tight_layout()
plt.show()
