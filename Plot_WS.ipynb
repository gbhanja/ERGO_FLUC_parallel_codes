# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_WS.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
E_ergo = data["Eerg"]
E_var = data["variance"]
E_ratio = data["ratio"]
E_B = data["Eb"]

# derived quantities
F_ratio = np.sqrt(E_var) / E_ergo
FE_ratio = np.sqrt(E_var) / E_B

# %%
N = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]

for i in range(len(N)):
    print(
        f"N={N[i]}, "
        f"τ={tau[i]:.6f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.6f}, "
        f"Ratio={ratio[i]:.6f}, "
        f"Variance={variance[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.10e}"
    )
# Out:
# N=2, τ=0.682200, Eb=1.058141, Ergotropy=1.020168, Ratio=0.964114, Variance=5.7360130333e-01,Fluctuation w.r.t erg=7.4239187643e-01,Fluctuation w.r.t EB=7.1575014257e-01
# N=6, τ=0.434400, Eb=3.629995, Ergotropy=3.569077, Ratio=0.983218, Variance=1.8187600085e+00,Fluctuation w.r.t erg=3.7786079442e-01,Fluctuation w.r.t EB=3.7151950632e-01
# N=10, τ=0.347800, Eb=6.304395, Ergotropy=6.233173, Ratio=0.988703, Variance=3.0741364854e+00,Fluctuation w.r.t erg=2.8128877604e-01,Fluctuation w.r.t EB=2.7811097277e-01
# N=14, τ=0.299600, Eb=9.026203, Ergotropy=8.948377, Ratio=0.991378, Variance=4.3325498451e+00,Fluctuation w.r.t erg=2.3260953906e-01,Fluctuation w.r.t EB=2.3060392857e-01
# N=18, τ=0.267800, Eb=11.781976, Ergotropy=11.699190, Ratio=0.992973, Variance=5.5926082320e+00,Fluctuation w.r.t erg=2.0213960925e-01,Fluctuation w.r.t EB=2.0071926948e-01
# N=22, τ=0.244800, Eb=14.565646, Ergotropy=14.478797, Ratio=0.994037, Variance=6.8537467661e+00,Fluctuation w.r.t erg=1.8081378580e-01,Fluctuation w.r.t EB=1.7973567525e-01
# N=26, τ=0.227200, Eb=17.375772, Ergotropy=17.285365, Ratio=0.994797, Variance=8.1157804446e+00,Fluctuation w.r.t erg=1.6481114580e-01,Fluctuation w.r.t EB=1.6395363135e-01
# N=30, τ=0.213100, Eb=20.203671, Ergotropy=20.110187, Ratio=0.995373, Variance=9.3781315175e+00,Fluctuation w.r.t erg=1.5227971125e-01,Fluctuation w.r.t EB=1.5157510552e-01
# N=34, τ=0.201500, Eb=23.050245, Ergotropy=22.953975, Ratio=0.995823, Variance=1.0640849099e+01,Fluctuation w.r.t erg=1.4211183349e-01,Fluctuation w.r.t EB=1.4151829597e-01
# N=38, τ=0.191800, Eb=25.921318, Ergotropy=25.822344, Ratio=0.996182, Variance=1.1904160612e+01,Fluctuation w.r.t erg=1.3361454357e-01,Fluctuation w.r.t EB=1.3310436642e-01
# N=42, τ=0.183400, Eb=28.797136, Ergotropy=28.695845, Ratio=0.996483, Variance=1.3167134468e+01,Fluctuation w.r.t erg=1.2645226814e-01,Fluctuation w.r.t EB=1.2600748278e-01
# N=46, τ=0.176200, Eb=31.703193, Ergotropy=31.599467, Ratio=0.996728, Variance=1.4430833206e+01,Fluctuation w.r.t erg=1.2021701681e-01,Fluctuation w.r.t EB=1.1982369216e-01
# N=50, τ=0.169800, Eb=34.613140, Ergotropy=34.507272, Ratio=0.996941, Variance=1.5694168014e+01,Fluctuation w.r.t erg=1.1480439855e-01,Fluctuation w.r.t EB=1.1445325432e-01
# N=54, τ=0.164100, Eb=37.534061, Ergotropy=37.426181, Ratio=0.997126, Variance=1.6957439436e+01,Fluctuation w.r.t erg=1.1002835721e-01,Fluctuation w.r.t EB=1.0971211360e-01
# N=58, τ=0.159000, Eb=40.469549, Ergotropy=40.359711, Ratio=0.997286, Variance=1.8220750675e+01,Fluctuation w.r.t erg=1.0576332134e-01,Fluctuation w.r.t EB=1.0547627052e-01
# N=62, τ=0.154400, Eb=43.418573, Ergotropy=43.306831, Ratio=0.997426, Variance=1.9484039998e+01,Fluctuation w.r.t erg=1.0192555969e-01,Fluctuation w.r.t EB=1.0166324429e-01
# N=66, τ=0.150200, Eb=46.374496, Ergotropy=46.260972, Ratio=0.997552, Variance=2.0747121155e+01,Fluctuation w.r.t erg=9.8460983439e-02,Fluctuation w.r.t EB=9.8219952605e-02
# N=70, τ=0.146400, Eb=49.352556, Ergotropy=49.237173, Ratio=0.997662, Variance=2.2010338695e+01,Fluctuation w.r.t erg=9.5284059576e-02,Fluctuation w.r.t EB=9.5061291567e-02
# N=74, τ=0.142900, Eb=52.339402, Ergotropy=52.222238, Ratio=0.997761, Variance=2.3273344983e+01,Fluctuation w.r.t erg=9.2379141817e-02,Fluctuation w.r.t EB=9.2172347969e-02
# N=78, τ=0.139700, Eb=55.347084, Ergotropy=55.228076, Ratio=0.997850, Variance=2.4536343321e+01,Fluctuation w.r.t erg=8.9690203467e-02,Fluctuation w.r.t EB=8.9497349367e-02
# N=82, τ=0.136700, Eb=58.353712, Ergotropy=58.233027, Ratio=0.997932, Variance=2.5798933519e+01,Fluctuation w.r.t erg=8.7223099223e-02,Fluctuation w.r.t EB=8.7042706373e-02
# N=86, τ=0.133900, Eb=61.366724, Ergotropy=61.244433, Ratio=0.998007, Variance=2.7061268309e+01,Fluctuation w.r.t erg=8.4939060736e-02,Fluctuation w.r.t EB=8.4769795897e-02
# N=90, τ=0.131300, Eb=64.394486, Ergotropy=64.270573, Ratio=0.998076, Variance=2.8323444671e+01,Fluctuation w.r.t erg=8.2805820880e-02,Fluctuation w.r.t EB=8.2646478378e-02
# N=94, τ=0.128800, Eb=67.403448, Ergotropy=67.278209, Ratio=0.998142, Variance=2.9585125002e+01,Fluctuation w.r.t erg=8.0846697043e-02,Fluctuation w.r.t EB=8.0696480449e-02
# N=98, τ=0.126500, Eb=70.441302, Ergotropy=70.314570, Ratio=0.998201, Variance=3.0846786231e+01,Fluctuation w.r.t erg=7.8987730194e-02,Fluctuation w.r.t EB=7.8845622541e-02
# N=102, τ=0.124400, Eb=73.518698, Ergotropy=73.390222, Ratio=0.998252, Variance=3.2108364889e+01,Fluctuation w.r.t erg=7.7209526821e-02,Fluctuation w.r.t EB=7.7074601173e-02
# N=106, τ=0.122300, Eb=76.545842, Ergotropy=76.416170, Ratio=0.998306, Variance=3.3369372402e+01,Fluctuation w.r.t erg=7.5594248088e-02,Fluctuation w.r.t EB=7.5466188682e-02
# N=110, τ=0.120400, Eb=79.625187, Ergotropy=79.493956, Ratio=0.998352, Variance=3.4630291177e+01,Fluctuation w.r.t erg=7.4027649451e-02,Fluctuation w.r.t EB=7.3905644022e-02
# N=114, τ=0.118600, Eb=82.713177, Ergotropy=82.580409, Ratio=0.998395, Variance=3.5890879282e+01,Fluctuation w.r.t erg=7.2546258479e-02,Fluctuation w.r.t EB=7.2429809847e-02
# N=118, τ=0.116800, Eb=85.755931, Ergotropy=85.622079, Ratio=0.998439, Variance=3.7151198688e+01,Fluctuation w.r.t erg=7.1186992723e-02,Fluctuation w.r.t EB=7.1075880464e-02
# N=122, τ=0.115200, Eb=88.873106, Ergotropy=88.737648, Ratio=0.998476, Variance=3.8411150788e+01,Fluctuation w.r.t erg=6.9842655769e-02,Fluctuation w.r.t EB=6.9736203599e-02
# N=126, τ=0.113600, Eb=91.950009, Ergotropy=91.813341, Ratio=0.998514, Variance=3.9670915402e+01,Fluctuation w.r.t erg=6.8600980095e-02,Fluctuation w.r.t EB=6.8499016417e-02
# N=130, τ=0.112100, Eb=95.050951, Ergotropy=94.912956, Ratio=0.998548, Variance=4.0930326473e+01,Fluctuation w.r.t erg=6.7405774478e-02,Fluctuation w.r.t EB=6.7307915378e-02
# N=134, τ=0.110700, Eb=98.181878, Ergotropy=98.042405, Ratio=0.998579, Variance=4.2189259345e+01,Fluctuation w.r.t erg=6.6250169826e-02,Fluctuation w.r.t EB=6.6156057192e-02
# N=138, τ=0.109300, Eb=101.276291, Ergotropy=101.135674, Ratio=0.998612, Variance=4.3448185948e+01,Fluctuation w.r.t erg=6.5175061712e-02,Fluctuation w.r.t EB=6.5084569274e-02
# N=142, τ=0.108000, Eb=104.407601, Ergotropy=104.265634, Ratio=0.998640, Variance=4.4706544555e+01,Fluctuation w.r.t erg=6.4127507696e-02,Fluctuation w.r.t EB=6.4040311557e-02
# N=146, τ=0.106700, Eb=107.503900, Ergotropy=107.360890, Ratio=0.998670, Variance=4.5965019350e+01,Fluctuation w.r.t erg=6.3149165997e-02,Fluctuation w.r.t EB=6.3065160545e-02
# N=150, τ=0.105500, Eb=110.644751, Ergotropy=110.500444, Ratio=0.998696, Variance=4.7222768008e+01,Fluctuation w.r.t erg=6.2188731245e-02,Fluctuation w.r.t EB=6.2107622236e-02
# N=154, τ=0.104400, Eb=113.837173, Ergotropy=113.691278, Ratio=0.998718, Variance=4.8479529556e+01,Fluctuation w.r.t erg=6.1242378400e-02,Fluctuation w.r.t EB=6.1163889556e-02
# N=158, τ=0.103300, Eb=117.000947, Ergotropy=116.853719, Ratio=0.998742, Variance=4.9736348954e+01,Fluctuation w.r.t erg=6.0352381510e-02,Fluctuation w.r.t EB=6.0276436955e-02
# N=162, τ=0.102200, Eb=120.134511, Ergotropy=119.986200, Ratio=0.998765, Variance=5.0993392512e+01,Fluctuation w.r.t erg=5.9514892443e-02,Fluctuation w.r.t EB=5.9441418997e-02
# N=166, τ=0.101100, Eb=123.236279, Ergotropy=123.087134, Ratio=0.998790, Variance=5.2250804873e+01,Fluctuation w.r.t erg=5.8726461547e-02,Fluctuation w.r.t EB=5.8655388598e-02
# N=170, τ=0.100100, Eb=126.401376, Ergotropy=126.251034, Ratio=0.998811, Variance=5.3506919611e+01,Fluctuation w.r.t erg=5.7938871324e-02,Fluctuation w.r.t EB=5.7869958967e-02
# N=174, τ=0.099200, Eb=129.637615, Ergotropy=129.485683, Ratio=0.998828, Variance=5.4761363316e+01,Fluctuation w.r.t erg=5.7149886771e-02,Fluctuation w.r.t EB=5.7082908526e-02
# N=178, τ=0.098200, Eb=132.747454, Ergotropy=132.594759, Ratio=0.998850, Variance=5.6018117389e+01,Fluctuation w.r.t erg=5.6446613913e-02,Fluctuation w.r.t EB=5.6381685284e-02
# N=182, τ=0.097300, Eb=135.932099, Ergotropy=135.778223, Ratio=0.998868, Variance=5.7273112408e+01,Fluctuation w.r.t erg=5.5737215924e-02,Fluctuation w.r.t EB=5.5674121015e-02
# N=186, τ=0.096500, Eb=139.199731, Ergotropy=139.044224, Ratio=0.998883, Variance=5.8525904604e+01,Fluctuation w.r.t erg=5.5020067014e-02,Fluctuation w.r.t EB=5.4958601404e-02
# N=190, τ=0.095600, Eb=142.334372, Ergotropy=142.178066, Ratio=0.998902, Variance=5.9781593775e+01,Fluctuation w.r.t erg=5.4381494912e-02,Fluctuation w.r.t EB=5.4321775247e-02
# N=194, τ=0.094800, Eb=145.556135, Ergotropy=145.398557, Ratio=0.998917, Variance=6.1034925647e+01,Fluctuation w.r.t erg=5.3731518530e-02,Fluctuation w.r.t EB=5.3673349171e-02
# N=198, τ=0.094000, Eb=148.755014, Ergotropy=148.596336, Ratio=0.998933, Variance=6.2288600150e+01,Fluctuation w.r.t erg=5.3112431540e-02,Fluctuation w.r.t EB=5.3055776176e-02
# N=202, τ=0.093200, Eb=151.930037, Ergotropy=151.770430, Ratio=0.998949, Variance=6.3542730806e+01,Fluctuation w.r.t erg=5.2522546457e-02,Fluctuation w.r.t EB=5.2467369829e-02

# %%
###############################################################
# Plot of battery ergotropy at optimal charging for different N 
###############################################################

plt.plot(N_arr, E_ergo, 'o-', color='c', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b$")
plt.title("Battery ergotropy at optimal charging time")
#plt.savefig("OP1")
plt.show()

# %%
###########################################################################
# Plot of variance of battery ergotropy at optimal charging for different N 
###########################################################################

plt.figure()
plt.plot(N_arr, E_var, 'd-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\mathrm{Var}(\mathcal{E}_b)$")
plt.title("Variance of battery ergotropy at optimal charging time")
#plt.savefig("OP2")
plt.show()

# %%
#############################################################
# Plot ergotropy fraction as a function of g for different N 
############################################################
    
plt.plot(N_arr, E_ratio, 'o-', color='g', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b / \langle E_b \rangle$")
plt.ylim(0,1.1)
plt.title("Ergotropy fraction at optimal charging time")
# plt.savefig("OP3")
plt.show()

# %%
######################################################
# Plot fluctuations as a function of g for different N 
######################################################

plt.plot(N_arr, F_ratio, 's-', color='r')
plt.xlabel("N")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
# plt.savefig("OP4")
plt.show()

# %%
##########################################################################
# Plot fluctuations w.r.t battery energy as function of g for different N 
##########################################################################

plt.figure()
plt.plot(N_arr, FE_ratio, 's-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/ \langle E_b \rangle$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\langle E_b \rangle$")
# plt.savefig("OP5")
plt.show()

# %% [markdown]
# ### Scaling of $1 - \mathcal{E}_b / \langle E_b \rangle$

# %%
###############################
# Scaling using a linear plot
##############################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function
def asymptotic_fit(N, A):
    return A / N

y_full = 1 - np.array(E_ratio)

# Restrict fitting data
N_data = N_arr[15:51]
y_data = 1 - np.array(E_ratio[15:51])

# Fit only restricted region
popt, pcov = curve_fit(asymptotic_fit, N_data, y_data)

A_opt = popt[0]

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_fit = asymptotic_fit(N_smooth, A_opt)

plt.figure(figsize=(7, 5))

# Plot the FULL dataset with faded colours 
plt.plot(N_arr, y_full, 'o', color='y', markersize=5, alpha=0.5, label=r"$1 - \mathcal{E}_b / \langle E_b \rangle$ data excluded")

# Plot restricted actual data
plt.plot(N_data, y_data, 'o', color='g', markersize=5, label=r"$1 - \mathcal{E}_b / \langle E_b \rangle$ fitted data")

# Plot fit over FULL range
plt.plot(N_smooth, y_fit, '-', color='r', linewidth=2, label=rf'Fit: $A/N$ ($A={A_opt:.6f}$)')

plt.xlabel("N")
plt.ylabel(r"$1 - \mathcal{E}_b / \langle E_b \rangle$")
plt.title("Scaling of Battery ergotropy fraction")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 0.177635

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit(log_N, logA):
    return logA - log_N

y_full = 1 - np.array(E_ratio)

# Restrict fitting data
N_data = N_arr[15:51]
y_data = y_full[15:51]

# Keep only positive values for the logarithm
mask = (N_data > 0) & (y_data > 0)

N_fit = N_data[mask]
y_fit_data = y_data[mask]

# Logarithmic variables
log_N = np.log(N_fit)
log_y = np.log(y_fit_data)

# Fit in log-space
popt, pcov = curve_fit(log_fit, log_N, log_y)

logA_opt = popt[0]
A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / N_smooth

plt.figure(figsize=(7, 5))

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ fitted data")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=rf'Fit: $\log y = \log A - \log N$')

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$")
plt.title("Logarithmic Scaling of Battery ergotropy fraction")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 0.187700

# %% [markdown]
# ### Scaling of $1 - \mathcal{E}_b / \langle E_b \rangle$

# %%
###############################
# Scaling using a linear plot
##############################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function
def asymptotic_fit(N, A):
    return A / N

y_full = np.array(F_ratio)

# Restrict fitting data
N_data = N_arr[20:51]
y_data = np.array(F_ratio[20:51])

# Fit only restricted region
popt, pcov = curve_fit(asymptotic_fit, N_data, y_data)

A_opt = popt[0]

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_fit = asymptotic_fit(N_smooth, A_opt)

plt.figure(figsize=(7, 5))

# Plot the FULL dataset with faded colours 
plt.plot(N_arr, y_full, 'o', color='y', markersize=5, alpha=0.5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data excluded")

# Plot restricted actual data
plt.plot(N_data, y_data, 'o', color='g', markersize=5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data fitted")

# Plot fit over FULL range
plt.plot(N_smooth, y_fit, '-', color='r', linewidth=2, label=rf'Fit: $A/N$ ($A={A_opt:.6f}$)')

plt.xlabel("N")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Scaling of Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 8.479527

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit(log_N, logA):
    return logA - log_N

y_full = np.array(F_ratio)

# Restrict fitting data
N_data = N_arr[15:51]
y_data = y_full[15:51]

# Keep only positive values for the logarithm
mask = (N_data > 0) & (y_data > 0)

N_fit = N_data[mask]
y_fit_data = y_data[mask]

# Logarithmic variables
log_N = np.log(N_fit)
log_y = np.log(y_fit_data)

# Fit in log-space
popt, pcov = curve_fit(log_fit, log_N, log_y)

logA_opt = popt[0]
A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / N_smooth

plt.figure(figsize=(7, 5))

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data fitted")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=rf'Fit: $\log y = \log A - \log N$')

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Logarithmic Scaling of Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 8.605453
