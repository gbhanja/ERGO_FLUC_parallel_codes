# %%
model = "Central Spin"

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os


downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "CS_Kac_OP_full_omega.npz")

data = np.load(filename)

# extract arrays
ω0_arr1 = data["ω0"]
tau1 = data["tau"]
E_ergo1 = data["Eerg"]
E_var1 = data["variance"]
E_ratio1 = data["ratio"]
E_B1 = data["Eb"]

# derived quantities
Power1 = E_B1 / tau1


F_ratio1 = np.sqrt(E_var1) / E_ergo1
FE_ratio1 = np.sqrt(E_var1) / E_B1

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os


downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "CS_Kac_OP_bosonic_omega.npz")

data = np.load(filename)

# extract arrays
ω0_arr2 = data["ω0"]
tau2 = data["tau"]
E_ergo2 = data["Eerg"]
E_var2 = data["variance"]
E_ratio2 = data["ratio"]
E_B2 = data["Eb"]


# derived quantities
Power2 = E_B2 / tau2


F_ratio2 = np.sqrt(E_var2) / E_ergo2
FE_ratio2 = np.sqrt(E_var2) / E_B2
# Out:
# /var/folders/__/qnt7415x1x54dvh7_jpmptp40000gp/T/ipykernel_2308/3885948264.py:26: RuntimeWarning: invalid value encountered in sqrt
#   F_ratio2 = np.sqrt(E_var2) / E_ergo2
# /var/folders/__/qnt7415x1x54dvh7_jpmptp40000gp/T/ipykernel_2308/3885948264.py:27: RuntimeWarning: invalid value encountered in sqrt
#   FE_ratio2 = np.sqrt(E_var2) / E_B2

# %%
for i in range(len(ω0_arr1)):
    print(
        f"ω0={ω0_arr1[i]}, "
        f"τ={tau1[i]:.6f}, "
        f"Eb={E_B1[i]:.12f}, "
        f"Ergotropy={E_ergo1[i]:.12f}, "
        f"Ratio={E_ratio1[i]:.6f}, "
        f"Variance={E_var1[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio1[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio1[i]:.10e}"
    )
# Out:
# ω0=1.0, τ=3.920000, Eb=42.248847157714, Ergotropy=41.434372297362, Ratio=0.980722, Variance=8.6651877527e+01,Fluctuation w.r.t erg=2.2466127778e-01,Fluctuation w.r.t EB=2.2033024924e-01
# ω0=1.5, τ=3.500000, Eb=47.070184238501, Ergotropy=45.813696494502, Ratio=0.973306, Variance=1.8750290321e+02,Fluctuation w.r.t erg=2.9888812724e-01,Fluctuation w.r.t EB=2.9090963141e-01
# ω0=2.0, τ=3.270000, Eb=40.028171040459, Ergotropy=38.314621267240, Ratio=0.957191, Variance=2.0376024177e+02,Fluctuation w.r.t erg=3.7255910931e-01,Fluctuation w.r.t EB=3.5661037719e-01
# ω0=2.5, τ=2.990000, Eb=24.881695044238, Ergotropy=22.672064055601, Ratio=0.911195, Variance=1.4609480496e+02,Fluctuation w.r.t erg=5.3312165863e-01,Fluctuation w.r.t EB=4.8577753133e-01
# ω0=3.0, τ=2.120000, Eb=9.521467419126, Ergotropy=7.067181336120, Ratio=0.742237, Variance=5.8705237484e+01,Fluctuation w.r.t erg=1.0841570285e+00,Fluctuation w.r.t EB=8.0470099620e-01
# ω0=3.5, τ=1.370000, Eb=4.138685497493, Ergotropy=2.166133889360, Ratio=0.523387, Variance=1.7259000211e+01,Fluctuation w.r.t erg=1.9178848125e+00,Fluctuation w.r.t EB=1.0037958407e+00
# ω0=4.0, τ=1.000000, Eb=2.482193463639, Ergotropy=0.916035790780, Ratio=0.369043, Variance=6.7353322582e+00,Fluctuation w.r.t erg=2.8331336986e+00,Fluctuation w.r.t EB=1.0455477810e+00
# ω0=4.5, τ=0.800000, Eb=1.773159862239, Ergotropy=0.482513803246, Ratio=0.272121, Variance=3.4496681203e+00,Fluctuation w.r.t erg=3.8492747947e+00,Fluctuation w.r.t EB=1.0474680036e+00
# ω0=5.0, τ=0.680000, Eb=1.399283424316, Ergotropy=0.294322707581, Ratio=0.210338, Variance=2.1214125059e+00,Fluctuation w.r.t erg=4.9486733986e+00,Fluctuation w.r.t EB=1.0408948811e+00

# %%
for i in range(len(ω0_arr2)):
    print(
        f"ω0={ω0_arr2[i]}, "
        f"τ={tau2[i]:.6f}, "
        f"Eb={E_B2[i]:.12f}, "
        f"Ergotropy={E_ergo2[i]:.12f}, "
        f"Ratio={E_ratio2[i]:.6f}, "
        f"Variance={E_var2[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio2[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio2[i]:.10e}"
    )
# Out:
# ω0=1.0, τ=3.920000, Eb=42.248847157714, Ergotropy=35.176914182176, Ratio=0.832612, Variance=3.4660251833e+02,Fluctuation w.r.t erg=5.2924664994e-01,Fluctuation w.r.t EB=4.4065732531e-01
# ω0=1.5, τ=3.500000, Eb=47.070184238501, Ergotropy=35.167701646279, Ratio=0.747133, Variance=7.7045552397e+02,Fluctuation w.r.t erg=7.8927764142e-01,Fluctuation w.r.t EB=5.8969560155e-01
# ω0=2.0, τ=3.270000, Eb=40.028171040459, Ergotropy=25.351122884077, Ratio=0.633332, Variance=8.1330769810e+02,Fluctuation w.r.t erg=1.1249422836e+00,Fluctuation w.r.t EB=7.1246198187e-01
# ω0=2.5, τ=2.990000, Eb=24.881695044238, Ergotropy=8.826338964036, Ratio=0.354732, Variance=5.0576091472e+02,Fluctuation w.r.t erg=2.5479566221e+00,Fluctuation w.r.t EB=9.0384231347e-01
# ω0=3.0, τ=2.120000, Eb=9.521467419126, Ergotropy=0.000000000000, Ratio=0.000000, Variance=5.6843418861e-14,Fluctuation w.r.t erg=1.3421772800e+08,Fluctuation w.r.t EB=2.5040108694e-08
# ω0=3.5, τ=1.370000, Eb=4.138685497493, Ergotropy=0.000000000000, Ratio=0.000000, Variance=5.6843418861e-14,Fluctuation w.r.t erg=2.6843545600e+08,Fluctuation w.r.t EB=5.7607319823e-08
# ω0=4.0, τ=1.000000, Eb=2.482193463639, Ergotropy=0.000000000000, Ratio=0.000000, Variance=-2.8421709430e-14,Fluctuation w.r.t erg=nan,Fluctuation w.r.t EB=nan
# ω0=4.5, τ=0.800000, Eb=1.773159862239, Ergotropy=-0.000000000000, Ratio=-0.000000, Variance=-1.9721522631e-31,Fluctuation w.r.t erg=nan,Fluctuation w.r.t EB=nan
# ω0=5.0, τ=0.680000, Eb=1.399283424316, Ergotropy=0.000000000000, Ratio=0.000000, Variance=-3.5527136788e-15,Fluctuation w.r.t erg=nan,Fluctuation w.r.t EB=nan

# %%
##########################################################
# Relative ergotropy fluctuations vs normalized ergotropy
##########################################################

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

N = 50

E_max_arr1 = ω0_arr1 * N
E_max_arr2 = ω0_arr2 * N

# Numerical data
x1 = E_ergo1 / E_max_arr1
y1 = F_ratio1

x2 = E_ergo2 / E_max_arr2
y2 = F_ratio2

# Domain for theoretical bounds
xb = np.linspace(0.01, 1.0, 400)

# Upper bounds
bound_finite = np.sqrt(1 / xb**2 - 1)
bound_largeN = np.sqrt(1 / xb - 1)

# --------------------------------------------------------
# Figure and axes
# --------------------------------------------------------

fig, ax = plt.subplots(figsize=(14, 6), dpi=400)

# --------------------------------------------------------
# Common normalization
# --------------------------------------------------------

norm = Normalize(
    vmin=min(ω0_arr1.min(), ω0_arr2.min()),
    vmax=max(ω0_arr1.max(), ω0_arr2.max())
)

# --------------------------------------------------------
# Numerical results
# --------------------------------------------------------

sc1 = ax.scatter(
    x1,
    y1,
    c=ω0_arr1,
    cmap='Blues',
    norm=norm,
    marker='o',
    s=45,
    edgecolors='k',
    linewidth=0.3,
    label='Distinguishable battery'
)

sc2 = ax.scatter(
    x2,
    y2,
    c=ω0_arr2,
    cmap='Reds',
    norm=norm,
    marker='s',
    s=45,
    edgecolors='k',
    linewidth=0.3,
    label='Indistinguishable battery'
)

# --------------------------------------------------------
# Theoretical bounds
# --------------------------------------------------------

ax.plot(
    xb,
    bound_finite,
    'r-',
    lw=2,
    label=r'General upper bound: $\sqrt{({\mathcal{E}_b/E_{\max}})^{-2}-1}$'
)

ax.plot(
    xb,
    bound_largeN,
    'g--',
    lw=2,
    label=r'Positive-work upper bound: $\sqrt{({\mathcal{E}_b/E_{\max}})^{-1}-1}$'
)

# --------------------------------------------------------
# Axis limits and labels
# --------------------------------------------------------

ax.set_xlim(-0.02, 1.0)
ax.set_ylim(0, 6)

ax.set_xlabel(
    r'$\mathcal{E}_b/E_{\max}$',
    fontsize=13
)

ax.set_ylabel(
    r'$\sigma_{\mathcal{E}_b}/\langle \mathcal{E}_b\rangle$',
    fontsize=13
)

ax.set_title(
    f"Relative ergotropy fluctuations and theoretical upper bounds of {model} model for N={N}",
    fontsize=11
)

# --------------------------------------------------------
# Colorbar for distinguishable battery
# --------------------------------------------------------

sm1 = ScalarMappable(
    norm=norm,
    cmap='Blues'
)

sm1.set_array([])

cbar1 = fig.colorbar(
    sm1,
    ax=ax,
    pad=0.02
)

cbar1.set_label(
    r'$\omega_B$ — distinguishable',
    fontsize=12
)

cbar1.set_ticks(
    [1, 3, 5]
)

# --------------------------------------------------------
# Colorbar for indistinguishable battery
# --------------------------------------------------------

sm2 = ScalarMappable(
    norm=norm,
    cmap='Reds'
)

sm2.set_array([])

cbar2 = fig.colorbar(
    sm2,
    ax=ax,
    pad=0.10
)

cbar2.set_label(
    r'$\omega_B$ — indistinguishable',
    fontsize=12
)

cbar2.set_ticks(
    [1, 3, 5]
)

# --------------------------------------------------------
# Legend
# --------------------------------------------------------

ax.legend(fontsize=10)

plt.tight_layout()
plt.show()
