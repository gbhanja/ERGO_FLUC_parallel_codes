# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_CS_OP.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
E_ergo = data["Eerg"]
E_var = data["variance"]
E_ratio = data["ratio"]
E_B = data["Eb"]

# derived quantities
F_ratio = np.sqrt(E_var) / E_ergo
FE_ratio = np.sqrt(E_var) / E_B

# %%
N = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]

for i in range(len(N)):
    print(
        f"N={N[i]}, "
        f"τ={tau[i]:.4f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.6f}, "
        f"Ratio={ratio[i]:.6f}, "
        f"Variance={variance[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.10e}"
    )
# Out:
# N=2, τ=0.8386, Eb=1.718138, Ergotropy=1.456137, Ratio=0.847509, Variance=8.5152359519e-01,Fluctuation w.r.t erg=6.3371801306e-01,Fluctuation w.r.t EB=5.3708169359e-01
# N=6, τ=0.4091, Eb=4.941554, Ergotropy=4.375822, Ratio=0.885515, Variance=2.0496420433e+00,Fluctuation w.r.t erg=3.2717441874e-01,Fluctuation w.r.t EB=2.8971800812e-01
# N=10, τ=0.2887, Eb=8.413815, Ergotropy=7.866566, Ratio=0.934958, Variance=4.8247021411e+00,Fluctuation w.r.t erg=2.7922228524e-01,Fluctuation w.r.t EB=2.6106118548e-01
# N=14, τ=0.2277, Eb=12.006336, Ergotropy=11.456878, Ratio=0.954236, Variance=8.0606341653e+00,Fluctuation w.r.t erg=2.4780970208e-01,Fluctuation w.r.t EB=2.3646894089e-01
# N=18, τ=0.1901, Eb=15.684417, Ergotropy=15.129646, Ratio=0.964629, Variance=1.1589198220e+01,Fluctuation w.r.t erg=2.2500798668e-01,Fluctuation w.r.t EB=2.1704925890e-01
# N=22, τ=0.1644, Eb=19.433993, Ergotropy=18.874868, Ratio=0.971230, Variance=1.5260545030e+01,Fluctuation w.r.t erg=2.0696699653e-01,Fluctuation w.r.t EB=2.0101245773e-01
# N=26, τ=0.1455, Eb=23.230032, Ergotropy=22.667735, Ratio=0.975794, Variance=1.9041057814e+01,Fluctuation w.r.t erg=1.9250295590e-01,Fluctuation w.r.t EB=1.8784330725e-01
# N=30, τ=0.1311, Eb=27.083830, Ergotropy=26.520458, Ratio=0.979199, Variance=2.2720886007e+01,Fluctuation w.r.t erg=1.7973457001e-01,Fluctuation w.r.t EB=1.7599590040e-01
# N=34, τ=0.1196, Eb=30.965631, Ergotropy=30.401919, Ratio=0.981796, Variance=2.6384459628e+01,Fluctuation w.r.t erg=1.6895580104e-01,Fluctuation w.r.t EB=1.6588005195e-01
# N=38, τ=0.1103, Eb=34.892729, Ergotropy=34.330090, Ratio=0.983875, Variance=2.9793796381e+01,Fluctuation w.r.t erg=1.5899665032e-01,Fluctuation w.r.t EB=1.5643285960e-01
# N=42, τ=0.1025, Eb=38.835263, Ergotropy=38.273741, Ratio=0.985541, Variance=3.3126643011e+01,Fluctuation w.r.t erg=1.5037921193e-01,Fluctuation w.r.t EB=1.4820486741e-01
# N=46, τ=0.0959, Eb=42.801445, Ergotropy=42.241322, Ratio=0.986913, Variance=3.6249564287e+01,Fluctuation w.r.t erg=1.4253249605e-01,Fluctuation w.r.t EB=1.4066723778e-01
# N=50, τ=0.0903, Eb=46.804161, Ergotropy=46.245811, Ratio=0.988071, Variance=3.8939194974e+01,Fluctuation w.r.t erg=1.3493390413e-01,Fluctuation w.r.t EB=1.3332421133e-01
# N=54, τ=0.0854, Eb=50.814390, Ergotropy=50.257225, Ratio=0.989035, Variance=4.1477036354e+01,Fluctuation w.r.t erg=1.2814608779e-01,Fluctuation w.r.t EB=1.2674100257e-01
# N=58, τ=0.0811, Eb=54.838965, Ergotropy=54.282450, Ratio=0.989852, Variance=4.3748882944e+01,Fluctuation w.r.t erg=1.2184958163e-01,Fluctuation w.r.t EB=1.2061303224e-01
# N=62, τ=0.0774, Eb=58.908831, Ergotropy=58.352097, Ratio=0.990549, Variance=4.5246408431e+01,Fluctuation w.r.t erg=1.1527512152e-01,Fluctuation w.r.t EB=1.1418568176e-01
# N=66, τ=0.0740, Eb=62.955957, Ergotropy=62.397967, Ratio=0.991137, Variance=4.6945345647e+01,Fluctuation w.r.t erg=1.0980593893e-01,Fluctuation w.r.t EB=1.0883270934e-01
# N=70, τ=0.0710, Eb=67.029487, Ergotropy=66.468732, Ratio=0.991634, Variance=4.8073566833e+01,Fluctuation w.r.t erg=1.0431236214e-01,Fluctuation w.r.t EB=1.0343970548e-01
# N=74, τ=0.0682, Eb=71.077739, Ergotropy=70.513898, Ratio=0.992067, Variance=4.9496062385e+01,Fluctuation w.r.t erg=9.9772441794e-02,Fluctuation w.r.t EB=9.8980973151e-02
# N=78, τ=0.0658, Eb=75.183658, Ergotropy=74.613226, Ratio=0.992413, Variance=4.9711021959e+01,Fluctuation w.r.t erg=9.4495369170e-02,Fluctuation w.r.t EB=9.3778416552e-02
# N=82, τ=0.0635, Eb=79.251709, Ergotropy=78.675137, Ratio=0.992725, Variance=5.0467406477e+01,Fluctuation w.r.t erg=9.0295890676e-02,Fluctuation w.r.t EB=8.9638970049e-02
# N=86, τ=0.0614, Eb=83.326114, Ergotropy=82.741947, Ratio=0.992989, Variance=5.0951622972e+01,Fluctuation w.r.t erg=8.6268704752e-02,Fluctuation w.r.t EB=8.5663908234e-02
# N=90, τ=0.0595, Eb=87.415155, Ergotropy=86.820992, Ratio=0.993203, Variance=5.0970365939e+01,Fluctuation w.r.t erg=8.2230727764e-02,Fluctuation w.r.t EB=8.1671802922e-02
# N=94, τ=0.0578, Eb=91.525768, Ergotropy=90.917838, Ratio=0.993358, Variance=5.0331689448e+01,Fluctuation w.r.t erg=7.8031805631e-02,Fluctuation w.r.t EB=7.7513504721e-02
# N=98, τ=0.0561, Eb=95.587150, Ergotropy=94.982928, Ratio=0.993679, Variance=5.1474988772e+01,Fluctuation w.r.t erg=7.5535755266e-02,Fluctuation w.r.t EB=7.5058281606e-02
# N=102, τ=0.0546, Eb=99.680386, Ergotropy=99.099552, Ratio=0.994173, Variance=5.1047097431e+01,Fluctuation w.r.t erg=7.2096442704e-02,Fluctuation w.r.t EB=7.1676338784e-02
# N=106, τ=0.0532, Eb=103.771214, Ergotropy=103.214111, Ratio=0.994631, Variance=5.0499761491e+01,Fluctuation w.r.t erg=6.8850260142e-02,Fluctuation w.r.t EB=6.8480632740e-02
# N=110, τ=0.0519, Eb=107.862991, Ergotropy=107.330728, Ratio=0.995065, Variance=4.9756431822e+01,Fluctuation w.r.t erg=6.5720451301e-02,Fluctuation w.r.t EB=6.5396146166e-02
# N=114, τ=0.0507, Eb=111.958348, Ergotropy=111.452795, Ratio=0.995484, Variance=4.8745911614e+01,Fluctuation w.r.t erg=6.2643805934e-02,Fluctuation w.r.t EB=6.2360934934e-02
# N=118, τ=0.0495, Eb=116.023384, Ergotropy=115.537897, Ratio=0.995816, Variance=4.8363346189e+01,Fluctuation w.r.t erg=6.0191298474e-02,Fluctuation w.r.t EB=5.9939434924e-02
# N=122, τ=0.0484, Eb=120.097051, Ergotropy=119.634448, Ratio=0.996148, Variance=4.7614989271e+01,Fluctuation w.r.t erg=5.7678717673e-02,Fluctuation w.r.t EB=5.7456544072e-02
# N=126, τ=0.0474, Eb=124.180414, Ergotropy=123.744192, Ratio=0.996487, Variance=4.6442530297e+01,Fluctuation w.r.t erg=5.5072286920e-02,Fluctuation w.r.t EB=5.4878828624e-02
# N=130, τ=0.0465, Eb=128.273349, Ergotropy=127.867533, Ratio=0.996836, Variance=4.4813745556e+01,Fluctuation w.r.t erg=5.2353453722e-02,Fluctuation w.r.t EB=5.2187824009e-02
# N=134, τ=0.0455, Eb=132.312988, Ergotropy=131.922471, Ratio=0.997049, Variance=4.4639149766e+01,Fluctuation w.r.t erg=5.0645303620e-02,Fluctuation w.r.t EB=5.0495825846e-02
# N=138, τ=0.0447, Eb=136.396162, Ergotropy=136.035299, Ratio=0.997354, Variance=4.2980522820e+01,Fluctuation w.r.t erg=4.8193030040e-02,Fluctuation w.r.t EB=4.8065525883e-02
# N=142, τ=0.0439, Eb=140.460210, Ergotropy=140.124058, Ratio=0.997607, Variance=4.1765511861e+01,Fluctuation w.r.t erg=4.6120732809e-02,Fluctuation w.r.t EB=4.6010355698e-02
# N=146, τ=0.0431, Eb=144.508253, Ergotropy=144.192163, Ratio=0.997813, Variance=4.0950620537e+01,Fluctuation w.r.t erg=4.4380131711e-02,Fluctuation w.r.t EB=4.4283056874e-02
# N=150, τ=0.0423, Eb=148.542861, Ergotropy=148.242512, Ratio=0.997978, Variance=4.0500290021e+01,Fluctuation w.r.t erg=4.2929546503e-02,Fluctuation w.r.t EB=4.2842744315e-02
# N=154, τ=0.0416, Eb=152.589432, Ergotropy=152.310120, Ratio=0.998170, Variance=3.9497333148e+01,Fluctuation w.r.t erg=4.1262461032e-02,Fluctuation w.r.t EB=4.1186930852e-02
# N=158, τ=0.0410, Eb=156.644095, Ergotropy=156.390697, Ratio=0.998382, Variance=3.8007841651e+01,Fluctuation w.r.t erg=3.9420823163e-02,Fluctuation w.r.t EB=3.9357053481e-02
# N=162, τ=0.0403, Eb=160.667128, Ergotropy=160.427056, Ratio=0.998506, Variance=3.7658777429e+01,Fluctuation w.r.t erg=3.8252118756e-02,Fluctuation w.r.t EB=3.8194961722e-02
# N=166, τ=0.0397, Eb=164.698338, Ergotropy=164.476570, Ratio=0.998653, Variance=3.6828398425e+01,Fluctuation w.r.t erg=3.6896687278e-02,Fluctuation w.r.t EB=3.6847005506e-02
# N=170, τ=0.0391, Eb=168.719874, Ergotropy=168.513013, Ratio=0.998774, Variance=3.6291495018e+01,Fluctuation w.r.t erg=3.5749418713e-02,Fluctuation w.r.t EB=3.5705587843e-02
# N=174, τ=0.0386, Eb=172.743474, Ergotropy=172.555480, Ratio=0.998912, Variance=3.5427408475e+01,Fluctuation w.r.t erg=3.4493791719e-02,Fluctuation w.r.t EB=3.4456252546e-02
# N=178, τ=0.0380, Eb=176.749555, Ergotropy=176.570570, Ratio=0.998987, Variance=3.5398278341e+01,Fluctuation w.r.t erg=3.3695565625e-02,Fluctuation w.r.t EB=3.3661443907e-02
# N=182, τ=0.0375, Eb=180.755864, Ergotropy=180.589587, Ratio=0.999080, Variance=3.5107663311e+01,Fluctuation w.r.t erg=3.2810153230e-02,Fluctuation w.r.t EB=3.2779971206e-02
# N=186, τ=0.0370, Eb=184.754711, Ergotropy=184.598389, Ratio=0.999154, Variance=3.5086217394e+01,Fluctuation w.r.t erg=3.2087831543e-02,Fluctuation w.r.t EB=3.2060681769e-02
# N=190, τ=0.0365, Eb=188.747934, Ergotropy=188.599261, Ratio=0.999212, Variance=3.5287303859e+01,Fluctuation w.r.t erg=3.1497004541e-02,Fluctuation w.r.t EB=3.1472194974e-02
# N=194, τ=0.0361, Eb=192.730087, Ergotropy=192.590661, Ratio=0.999277, Variance=3.5615074470e+01,Fluctuation w.r.t erg=3.0987155072e-02,Fluctuation w.r.t EB=3.0964738058e-02
# N=198, τ=0.0356, Eb=196.714150, Ergotropy=196.578433, Ratio=0.999310, Variance=3.6221067947e+01,Fluctuation w.r.t erg=3.0615739693e-02,Fluctuation w.r.t EB=3.0594617319e-02
# N=202, τ=0.0352, Eb=200.682692, Ergotropy=200.551571, Ratio=0.999347, Variance=3.7144365899e+01,Fluctuation w.r.t erg=3.0389279649e-02,Fluctuation w.r.t EB=3.0369424033e-02

# %%
###############################################################
# Plot of battery ergotropy at optimal charging for different N 
###############################################################

plt.plot(N_arr, E_ergo, 'o-', color='c', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b$")
plt.title("Battery ergotropy at optimal charging time")
#plt.savefig("OP1")
plt.show()

# %%
###########################################################################
# Plot of variance of battery ergotropy at optimal charging for different N 
###########################################################################

plt.figure()
plt.plot(N_arr, E_var, 'd-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\mathrm{Var}(\mathcal{E}_b)$")
plt.title("Variance of battery ergotropy at optimal charging time")
#plt.savefig("OP2")
plt.show()

# %%
#############################################################
# Plot ergotropy fraction as a function of g for different N 
############################################################
    
plt.plot(N_arr, E_ratio, 'o-', color='g', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b / \langle E_b \rangle$")
plt.ylim(0,1.1)
plt.title("Ergotropy fraction at optimal charging time")
# plt.savefig("OP3")
plt.show()

# %%
######################################################
# Plot fluctuations as a function of g for different N 
######################################################

plt.plot(N_arr, F_ratio, 's-', color='r')
plt.xlabel("N")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
# plt.savefig("OP4")
plt.show()

# %%
##########################################################################
# Plot fluctuations w.r.t battery energy as function of g for different N 
##########################################################################

plt.figure()
plt.plot(N_arr, FE_ratio, 's-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/ \langle E_b \rangle$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\langle E_b \rangle$")
# plt.savefig("OP5")
plt.show()

# %%
###############################
# Scaling using a linear plot
##############################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function
def asymptotic_fit(N, A):
    return A / N

y_full = 1 - np.array(E_ratio)

# Restrict fitting data
N_data = N_arr[30:51]
y_data = 1 - np.array(E_ratio[30:51])

# Fit only restricted region
popt, pcov = curve_fit(asymptotic_fit, N_data, y_data)

A_opt = popt[0]

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_fit = asymptotic_fit(N_smooth, A_opt)

plt.figure(figsize=(7, 5))

# Plot the FULL dataset with faded colours 
plt.plot(N_arr, y_full, 'o', color='y', markersize=5, alpha=0.5, label=r"$1 - \mathcal{E}_b / \langle E_b \rangle$ data excluded")

# Plot restricted actual data
plt.plot(N_data, y_data, 'o', color='g', markersize=5, label=r"$1 - \mathcal{E}_b / \langle E_b \rangle$ fitted data")

# Plot fit over FULL range
plt.plot(N_smooth, y_fit, '-', color='r', linewidth=2, label=rf'Fit: $A/N$ ($A={A_opt:.6f}$)')

plt.xlabel("N")
plt.ylabel(r"$1 - \mathcal{E}_b / \langle E_b \rangle$")
plt.title("Scaling of Battery ergotropy fraction")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 0.295111

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit(log_N, logA, alpha):
    return logA - alpha *log_N

y_full = 1 - np.array(E_ratio)

# Restrict fitting data
N_data = N_arr[20:51]
y_data = y_full[20:51]

# Keep only positive values for the logarithm
mask = (N_data > 0) & (y_data > 0)

N_fit = N_data[mask]
y_fit_data = y_data[mask]

# Logarithmic variables
log_N = np.log(N_fit)
log_y = np.log(y_fit_data)

# Fit in log-space
popt, pcov = curve_fit(log_fit, log_N, log_y)

logA_opt, alpha_opt = popt

A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}, alpha = {alpha_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / (N_smooth**alpha_opt)

plt.figure(figsize=(7, 5))

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ fitted data")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=rf'Fit: $\log y = \log A - \alpha\log N$')

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$")
plt.title("Logarithmic Scaling of Battery ergotropy fraction")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 4230.642045, alpha = 2.928093

# %% [markdown]
# ### Scaling of $\sqrt var(\mathcal{E}_b) / \mathcal{E}_b$

# %%
###############################
# Scaling using a linear plot
##############################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function
def asymptotic_fit(N, A):
    return A / N

y_full = np.array(F_ratio)

# Restrict fitting data
N_data = N_arr[15:51]
y_data = np.array(F_ratio[15:51])

# Fit only restricted region
popt, pcov = curve_fit(asymptotic_fit, N_data, y_data)

A_opt = popt[0]

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_fit = asymptotic_fit(N_smooth, A_opt)

plt.figure(figsize=(7, 5))

# Plot the FULL dataset with faded colours 
plt.plot(N_arr, y_full, 'o', color='y', markersize=5, alpha=0.5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data excluded")

# Plot restricted actual data
plt.plot(N_data, y_data, 'o', color='g', markersize=5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data fitted")

# Plot fit over FULL range
plt.plot(N_smooth, y_fit, '-', color='r', linewidth=2, label=rf'Fit: $A/N$ ($A={A_opt:.6f}$)')

plt.xlabel("N")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Scaling of Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 7.047364

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit(log_N, logA):
    return logA - log_N

y_full = np.array(F_ratio)

# Restrict fitting data
N_data = N_arr[20:51]
y_data = y_full[20:51]

# Keep only positive values for the logarithm
mask = (N_data > 0) & (y_data > 0)

N_fit = N_data[mask]
y_fit_data = y_data[mask]

# Logarithmic variables
log_N = np.log(N_fit)
log_y = np.log(y_fit_data)

# Fit in log-space
popt, pcov = curve_fit(log_fit, log_N, log_y)

logA_opt = popt[0]
A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / N_smooth

plt.figure()

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data fitted")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=rf'Fit: $\log y = \log A - \log N$')

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Logarithmic Scaling of Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 6.619657
