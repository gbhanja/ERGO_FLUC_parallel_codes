# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "Fluc_erg_CS_Kac_WS.npz")

data = np.load(filename)

# extract arrays
N_arr = data["N"]
E_ergo = data["Eerg"]
E_var = data["variance"]
E_ratio = data["ratio"]
E_B = data["Eb"]

# derived quantities
F_ratio = np.sqrt(E_var) / E_ergo
FE_ratio = np.sqrt(E_var) / E_B

# %%
N = data["N"]
tau = data["tau"]
Eb = data["Eb"]
Eerg = data["Eerg"]
ratio = data["ratio"]
variance = data["variance"]

for i in range(len(N)):
    print(
        f"N={N[i]}, "
        f"τ={tau[i]:.6f}, "
        f"Eb={Eb[i]:.6f}, "
        f"Ergotropy={Eerg[i]:.6f}, "
        f"Ratio={ratio[i]:.6f}, "
        f"Variance={variance[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio[i]:.10e}"
    )
# Out:
# N=2, τ=1.180000, Eb=1.709793, Ergotropy=1.440640, Ratio=0.842582, Variance=8.6900148192e-01,Fluctuation w.r.t erg=6.4707516002e-01,Fluctuation w.r.t EB=5.4521379585e-01
# N=6, τ=0.982100, Eb=4.849158, Ergotropy=4.296836, Ratio=0.886099, Variance=2.2342495159e+00,Fluctuation w.r.t erg=3.4787005645e-01,Fluctuation w.r.t EB=3.0824747651e-01
# N=10, τ=0.884200, Eb=8.172562, Ergotropy=7.622709, Ratio=0.932720, Variance=5.4895961315e+00,Fluctuation w.r.t erg=3.0736956805e-01,Fluctuation w.r.t EB=2.8668962241e-01
# N=14, τ=0.816400, Eb=11.562063, Ergotropy=10.984431, Ratio=0.950041, Variance=9.5743665022e+00,Fluctuation w.r.t erg=2.8169391918e-01,Fluctuation w.r.t EB=2.6762068439e-01
# N=18, τ=0.765000, Eb=14.987682, Ergotropy=14.375202, Ratio=0.959134, Variance=1.4435739995e+01,Fluctuation w.r.t erg=2.6430511611e-01,Fluctuation w.r.t EB=2.5350414737e-01
# N=22, τ=0.724000, Eb=18.436889, Ergotropy=17.789038, Ratio=0.964861, Variance=2.0058092030e+01,Fluctuation w.r.t erg=2.5176325712e-01,Fluctuation w.r.t EB=2.4291658667e-01
# N=26, τ=0.690300, Eb=21.907254, Ergotropy=21.226271, Ratio=0.968915, Variance=2.6415695926e+01,Fluctuation w.r.t erg=2.4213486308e-01,Fluctuation w.r.t EB=2.3460814163e-01
# N=30, τ=0.661800, Eb=25.392108, Ergotropy=24.680688, Ratio=0.971983, Variance=3.3512251369e+01,Fluctuation w.r.t erg=2.3455491682e-01,Fluctuation w.r.t EB=2.2798330561e-01
# N=34, τ=0.637200, Eb=28.887398, Ergotropy=28.148268, Ratio=0.974413, Variance=4.1351167453e+01,Fluctuation w.r.t erg=2.2845054919e-01,Fluctuation w.r.t EB=2.2260528230e-01
# N=38, τ=0.615700, Eb=32.393752, Ergotropy=31.629786, Ratio=0.976416, Variance=4.9913043827e+01,Fluctuation w.r.t erg=2.2336276096e-01,Fluctuation w.r.t EB=2.1809503477e-01
# N=42, τ=0.596700, Eb=35.911254, Ergotropy=35.125209, Ratio=0.978111, Variance=5.9178878471e+01,Fluctuation w.r.t erg=2.1901025093e-01,Fluctuation w.r.t EB=2.1421643643e-01
# N=46, τ=0.579700, Eb=39.436854, Ergotropy=38.633313, Ratio=0.979625, Variance=6.8787541591e+01,Fluctuation w.r.t erg=2.1468066764e-01,Fluctuation w.r.t EB=2.1030646770e-01
# N=50, τ=0.564400, Eb=42.972606, Ergotropy=42.167175, Ratio=0.981257, Variance=7.9641961618e+01,Fluctuation w.r.t erg=2.1163937201e-01,Fluctuation w.r.t EB=2.0767264165e-01
# N=54, τ=0.550500, Eb=46.515960, Ergotropy=45.707701, Ratio=0.982624, Variance=9.1169169581e+01,Fluctuation w.r.t erg=2.0889816535e-01,Fluctuation w.r.t EB=2.0526835854e-01
# N=58, τ=0.537800, Eb=50.067131, Ergotropy=49.255337, Ratio=0.983786, Variance=1.0334821279e+02,Fluctuation w.r.t erg=2.0639453348e-01,Fluctuation w.r.t EB=2.0304802805e-01
# N=62, τ=0.526100, Eb=53.622833, Ergotropy=52.806941, Ratio=0.984785, Variance=1.1620078455e+02,Fluctuation w.r.t erg=2.0413314319e-01,Fluctuation w.r.t EB=2.0102717678e-01
# N=66, τ=0.515300, Eb=57.185651, Ergotropy=56.365283, Ratio=0.985654, Variance=1.2968241861e+02,Fluctuation w.r.t erg=2.0203604474e-01,Fluctuation w.r.t EB=1.9913769758e-01
# N=70, τ=0.505300, Eb=60.756719, Ergotropy=59.931649, Ratio=0.986420, Variance=1.4376083634e+02,Fluctuation w.r.t erg=2.0006175175e-01,Fluctuation w.r.t EB=1.9734493339e-01
# N=74, τ=0.495900, Eb=64.323800, Ergotropy=63.493669, Ratio=0.987094, Variance=1.5859559052e+02,Fluctuation w.r.t erg=1.9834220114e-01,Fluctuation w.r.t EB=1.9578249536e-01
# N=78, τ=0.487200, Eb=67.906577, Ergotropy=67.071483, Ratio=0.987702, Variance=1.7389335038e+02,Fluctuation w.r.t erg=1.9660908350e-01,Fluctuation w.r.t EB=1.9419124623e-01
# N=82, τ=0.479000, Eb=71.489270, Ergotropy=70.649070, Ratio=0.988247, Variance=1.8987270808e+02,Fluctuation w.r.t erg=1.9504051007e-01,Fluctuation w.r.t EB=1.9274823507e-01
# N=86, τ=0.471300, Eb=75.078489, Ergotropy=74.233223, Ratio=0.988742, Variance=2.0642193111e+02,Fluctuation w.r.t erg=1.9354395100e-01,Fluctuation w.r.t EB=1.9136494855e-01
# N=90, τ=0.464000, Eb=78.666601, Ergotropy=77.816192, Ratio=0.989190, Variance=2.2366169941e+02,Fluctuation w.r.t erg=1.9218780816e-01,Fluctuation w.r.t EB=1.9011020317e-01
# N=94, τ=0.457100, Eb=82.259007, Ergotropy=81.403526, Ratio=0.989600, Variance=2.4149462639e+02,Fluctuation w.r.t erg=1.9090201831e-01,Fluctuation w.r.t EB=1.8891666698e-01
# N=98, τ=0.450600, Eb=85.861675, Ergotropy=85.001339, Ratio=0.989980, Variance=2.5979483217e+02,Fluctuation w.r.t erg=1.8962233328e-01,Fluctuation w.r.t EB=1.8772231415e-01
# N=102, τ=0.444400, Eb=89.463432, Ergotropy=88.598251, Ratio=0.990329, Variance=2.7876391882e+02,Fluctuation w.r.t erg=1.8844869339e-01,Fluctuation w.r.t EB=1.8662624904e-01
# N=106, τ=0.438500, Eb=93.068512, Ergotropy=92.198600, Ratio=0.990653, Variance=2.9831536880e+02,Fluctuation w.r.t erg=1.8733265511e-01,Fluctuation w.r.t EB=1.8558165466e-01
# N=110, τ=0.432900, Eb=96.681538, Ergotropy=95.807108, Ratio=0.990956, Variance=3.1834023318e+02,Fluctuation w.r.t erg=1.8622931020e-01,Fluctuation w.r.t EB=1.8454497172e-01
# N=114, τ=0.427600, Eb=100.307484, Ergotropy=99.428849, Ratio=0.991241, Variance=3.3870606205e+02,Fluctuation w.r.t erg=1.8509686946e-01,Fluctuation w.r.t EB=1.8347552941e-01
# N=118, τ=0.422400, Eb=103.908954, Ergotropy=103.025729, Ratio=0.991500, Variance=3.6026230900e+02,Fluctuation w.r.t erg=1.8423142782e-01,Fluctuation w.r.t EB=1.8266546249e-01
# N=122, τ=0.417500, Eb=107.530493, Ergotropy=106.643136, Ratio=0.991748, Variance=3.8198367281e+02,Fluctuation w.r.t erg=1.8326920288e-01,Fluctuation w.r.t EB=1.8175683966e-01
# N=126, τ=0.412800, Eb=111.154704, Ergotropy=110.263348, Ratio=0.991981, Variance=4.0425928426e+02,Fluctuation w.r.t erg=1.8234708470e-01,Fluctuation w.r.t EB=1.8088483341e-01
# N=130, τ=0.408300, Eb=114.784835, Ergotropy=113.889670, Ratio=0.992201, Variance=4.2699805844e+02,Fluctuation w.r.t erg=1.8143815266e-01,Fluctuation w.r.t EB=1.8002318270e-01
# N=134, τ=0.404000, Eb=118.424343, Ergotropy=117.525611, Ratio=0.992411, Variance=4.5009225733e+02,Fluctuation w.r.t erg=1.8051706081e-01,Fluctuation w.r.t EB=1.7914710206e-01
# N=138, τ=0.399800, Eb=122.050695, Ergotropy=121.150315, Ratio=0.992623, Variance=4.7400374315e+02,Fluctuation w.r.t erg=1.7970755536e-01,Fluctuation w.r.t EB=1.7838183637e-01
# N=142, τ=0.395800, Eb=125.691945, Ergotropy=124.790407, Ratio=0.992827, Variance=4.9831293645e+02,Fluctuation w.r.t erg=1.7888333398e-01,Fluctuation w.r.t EB=1.7760027518e-01
# N=146, τ=0.391900, Eb=129.323911, Ergotropy=128.421117, Ratio=0.993019, Variance=5.2348785011e+02,Fluctuation w.r.t erg=1.7816273032e-01,Fluctuation w.r.t EB=1.7691899844e-01
# N=150, τ=0.388200, Eb=132.976934, Ergotropy=132.072957, Ratio=0.993202, Variance=5.4862278738e+02,Fluctuation w.r.t erg=1.7734666298e-01,Fluctuation w.r.t EB=1.7614105955e-01
# N=154, τ=0.384600, Eb=136.625117, Ergotropy=135.719893, Ratio=0.993374, Variance=5.7447947535e+02,Fluctuation w.r.t erg=1.7660124118e-01,Fluctuation w.r.t EB=1.7543115117e-01
# N=158, τ=0.381100, Eb=140.269858, Ergotropy=139.363335, Ratio=0.993537, Variance=6.0102497548e+02,Fluctuation w.r.t erg=1.7591291698e-01,Fluctuation w.r.t EB=1.7477604289e-01
# N=162, τ=0.377700, Eb=143.912657, Ergotropy=143.004793, Ratio=0.993692, Variance=6.2821835291e+02,Fluctuation w.r.t erg=1.7526884193e-01,Fluctuation w.r.t EB=1.7416316849e-01
# N=166, τ=0.374400, Eb=147.555110, Ergotropy=146.645875, Ratio=0.993838, Variance=6.5601032086e+02,Fluctuation w.r.t erg=1.7465679478e-01,Fluctuation w.r.t EB=1.7358055841e-01
# N=170, τ=0.371200, Eb=151.198907, Ergotropy=150.288285, Ratio=0.993977, Variance=6.8434290985e+02,Fluctuation w.r.t erg=1.7406512183e-01,Fluctuation w.r.t EB=1.7301678391e-01
# N=174, τ=0.368200, Eb=154.881230, Ergotropy=153.969444, Ratio=0.994113, Variance=7.1188539098e+02,Fluctuation w.r.t erg=1.7328880196e-01,Fluctuation w.r.t EB=1.7226865012e-01
# N=178, τ=0.365200, Eb=158.534215, Ergotropy=157.621065, Ratio=0.994240, Variance=7.4102016768e+02,Fluctuation w.r.t erg=1.7270334789e-01,Fluctuation w.r.t EB=1.7170858428e-01
# N=182, τ=0.362300, Eb=162.194148, Ergotropy=161.279664, Ratio=0.994362, Variance=7.7046488352e+02,Fluctuation w.r.t erg=1.7210631821e-01,Fluctuation w.r.t EB=1.7113594804e-01
# N=186, τ=0.359500, Eb=165.863052, Ergotropy=164.947282, Ratio=0.994479, Variance=8.0012440122e+02,Fluctuation w.r.t erg=1.7148794393e-01,Fluctuation w.r.t EB=1.7054111740e-01
# N=190, τ=0.356700, Eb=169.503377, Ergotropy=168.586127, Ratio=0.994589, Variance=8.3144456876e+02,Fluctuation w.r.t erg=1.7103886908e-01,Fluctuation w.r.t EB=1.7011331012e-01
# N=194, τ=0.354100, Eb=173.195520, Ergotropy=172.277118, Ratio=0.994697, Variance=8.6128554035e+02,Fluctuation w.r.t erg=1.7035150714e-01,Fluctuation w.r.t EB=1.6944818597e-01
# N=198, τ=0.351500, Eb=176.861316, Ergotropy=175.941587, Ratio=0.994800, Variance=8.9270525457e+02,Fluctuation w.r.t erg=1.6981871133e-01,Fluctuation w.r.t EB=1.6893560558e-01
# N=202, τ=0.348900, Eb=180.499779, Ergotropy=179.578543, Ratio=0.994896, Variance=9.2581240372e+02,Fluctuation w.r.t erg=1.6943653243e-01,Fluctuation w.r.t EB=1.6857176075e-01

# %%
###############################################################
# Plot of battery ergotropy at optimal charging for different N 
###############################################################

plt.plot(N_arr, E_ergo, 'o-', color='c', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b$")
plt.title("Battery ergotropy at optimal charging time")
plt.show()

# %%
###########################################################################
# Plot of variance of battery ergotropy at optimal charging for different N 
###########################################################################

plt.figure()
plt.plot(N_arr, E_var, 'd-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\mathrm{Var}(\mathcal{E}_b)$")
plt.title("Variance of battery ergotropy at optimal charging time")
plt.show()

# %%
#############################################################
# Plot ergotropy fraction as a function of g for different N 
############################################################
    
plt.plot(N_arr, E_ratio, 'o-', color='g', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$\mathcal{E}_b / \langle E_b \rangle$")
plt.ylim(0,1.1)
plt.title("Ergotropy fraction at optimal charging time")
plt.show()

# %%
#############################################################
# Plot ergotropy fraction as a function of g for different N 
############################################################
    
plt.plot(N_arr, 1 - E_ratio, 'o-', color='brown', linewidth=2)
plt.xlabel("N")
plt.ylabel(r"$1 - \mathcal{E}_b / \langle E_b \rangle$")
plt.title("Ergotropy fraction at optimal charging time")
plt.show()

# %%
######################################################
# Plot fluctuations as a function of g for different N 
######################################################

plt.plot(N_arr, F_ratio, 's-', color='r')
plt.xlabel("N")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.show()

# %%
##########################################################################
# Plot fluctuations w.r.t battery energy as function of g for different N 
##########################################################################

plt.figure()
plt.plot(N_arr, FE_ratio, 's-', color='b')
plt.xlabel(r"$N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/ \langle E_b \rangle$")
plt.title(r"Relative ergotropy fluctuations w.r.t $\langle E_b \rangle$")
plt.show()

# %% [markdown]
# ### Scaling of $1 - \mathcal{E}_b / E_{b}$

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit1(log_N, logA, alpha1):
    return logA - alpha1 *log_N

y_full = 1 - np.array(E_ratio)

# Restrict fitting data
N_data1 = N_arr[33:51]
y_data1 = y_full[33:51]

# Keep only positive values for the logarithm
mask = (N_data1 > 0) & (y_data1 > 0)

N_fit1 = N_data1[mask]
y_fit_data1 = y_data1[mask]

# Logarithmic variables
log_N = np.log(N_fit1)
log_y = np.log(y_fit_data1)

# Fit in log-space
popt, pcov = curve_fit(log_fit1, log_N, log_y)

logA_opt, alpha_opt = popt

A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}, alpha = {alpha_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / (N_smooth**alpha_opt)

plt.figure(figsize=(7, 5))

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$ fitted data")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=(
        rf'Fit: $\log y = \log A - \alpha \log N$'
        '\n'
        rf'$A={A_opt:.4f},\ \alpha={alpha_opt:.4f}$'))

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\log\left(1 - \mathcal{E}_b / \langle E_b \rangle\right)$")
plt.title("Logarithmic Scaling of Battery ergotropy fraction")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 0.866851, alpha = 0.967535

# %% [markdown]
# ### Scaling of $\sqrt var(\mathcal{E}_b) / \mathcal{E}_b$

# %%
###################################
# Scaling using a logarithmic plot
###################################

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fitting function in log-space
def log_fit2(log_N, logA, alpha2):
    return logA - alpha2 *log_N

y_full = np.array(F_ratio)

# Restrict fitting data
N_data2 = N_arr[15:51]
y_data2 = y_full[15:51]

# Keep only positive values for the logarithm
mask = (N_data2 > 0) & (y_data2 > 0)

N_fit2 = N_data2[mask]
y_fit_data2 = y_data2[mask]

# Logarithmic variables
log_N = np.log(N_fit2)
log_y = np.log(y_fit_data2)

# Fit in log-space
popt, pcov = curve_fit(log_fit2, log_N, log_y)

logA_opt, alpha_opt = popt

A_opt = np.exp(logA_opt)

print(f"Best fit parameter: A = {A_opt:.6f}, alpha = {alpha_opt:.6f}")

# Smooth curve over FULL N range
N_smooth = np.linspace(min(N_arr), max(N_arr), 300)

y_smooth = A_opt / (N_smooth**alpha_opt)

plt.figure(figsize=(7, 5))

# Plot FULL dataset with faded colours
plt.plot(np.log(N_arr[y_full > 0]), np.log(y_full[y_full > 0]), 'o', color='y', markersize=5, alpha=0.5,label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data excluded")

# Plot restricted fitted data
plt.plot(log_N, log_y, 'o', color='g', markersize=5, label=r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$ data fitted")

# Plot fitted line over FULL range
plt.plot(np.log(N_smooth), np.log(y_smooth), '-', color='r', linewidth=2, label=(
        rf'Fit: $\log y = \log A - \alpha \log N$'
        '\n'
        rf'$A={A_opt:.4f},\ \alpha={alpha_opt:.4f}$'))

plt.xlabel(r"$\log N$")
plt.ylabel(r"$\sqrt{\mathrm{Var}(\mathcal{E}_b)}/\mathcal{E}_b$")
plt.title(r"Logarithmic Scaling of Relative ergotropy fluctuations w.r.t $\mathcal{E}_b$")
plt.legend()
plt.show()
# Out:
# Best fit parameter: A = 0.390448, alpha = 0.157440
