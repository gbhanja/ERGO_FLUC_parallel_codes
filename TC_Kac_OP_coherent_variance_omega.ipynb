# %%
model = "Tavis-Cummings"

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os


downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "TC_Kac_OP_coherent_full_omega.npz")

data = np.load(filename)

# extract arrays
ω0_arr1 = data["ω0"]
tau1 = data["tau"]
E_ergo1 = data["Eerg"]
E_var1 = data["variance"]
E_ratio1 = data["ratio"]
E_B1 = data["Eb"]

# derived quantities
Power1 = E_B1 / tau1


F_ratio1 = np.sqrt(E_var1) / E_ergo1
FE_ratio1 = np.sqrt(E_var1) / E_B1

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os


downloads = os.path.join(os.path.expanduser("~"), "Downloads")

filename = os.path.join(downloads, "TC_Kac_OP_coherent_bosonic_omega.npz")

data = np.load(filename)

# extract arrays
ω0_arr2 = data["ω0"]
tau2 = data["tau"]
E_ergo2 = data["Eerg"]
E_var2 = data["variance"]
E_ratio2 = data["ratio"]
E_B2 = data["Eb"]


# derived quantities
Power2 = E_B2 / tau2


F_ratio2 = np.sqrt(E_var2) / E_ergo2
FE_ratio2 = np.sqrt(E_var2) / E_B2

# %%
for i in range(len(ω0_arr1)):
    print(
        f"ω0={ω0_arr1[i]}, "
        f"τ={tau1[i]:.6f}, "
        f"Eb={E_B1[i]:.12f}, "
        f"Ergotropy={E_ergo1[i]:.12f}, "
        f"Ratio={E_ratio1[i]:.6f}, "
        f"Variance={E_var1[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio1[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio1[i]:.10e}"
    )
# Out:
# ω0=1.0, τ=1.081973, Eb=31.420878513566, Ergotropy=31.353843747086, Ratio=0.997867, Variance=1.5487824549e+01,Fluctuation w.r.t erg=1.2551754041e-01,Fluctuation w.r.t EB=1.2524975544e-01
# ω0=1.5, τ=1.021919, Eb=28.847325024955, Ergotropy=28.772059145426, Ratio=0.997391, Variance=1.5396280819e+01,Fluctuation w.r.t erg=1.3637569206e-01,Fluctuation w.r.t EB=1.3601987271e-01
# ω0=2.0, τ=0.921829, Eb=24.261588229341, Ergotropy=24.203650895273, Ratio=0.997612, Variance=1.4642654524e+01,Fluctuation w.r.t erg=1.5809896533e-01,Fluctuation w.r.t EB=1.5772142069e-01
# ω0=2.5, τ=0.811730, Eb=19.519046619327, Ergotropy=19.482656361381, Ratio=0.998136, Variance=1.3144324326e+01,Fluctuation w.r.t erg=1.8608911171e-01,Fluctuation w.r.t EB=1.8574217720e-01
# ω0=3.0, τ=0.721649, Eb=15.732277266888, Ergotropy=15.709623756305, Ratio=0.998560, Variance=1.1494803596e+01,Fluctuation w.r.t erg=2.1581667325e-01,Fluctuation w.r.t EB=2.1550591052e-01
# ω0=3.5, τ=0.651586, Eb=12.862579843565, Ergotropy=12.847899235445, Ratio=0.998859, Variance=9.9772419945e+00,Fluctuation w.r.t erg=2.4585165217e-01,Fluctuation w.r.t EB=2.4557105125e-01
# ω0=4.0, τ=0.581523, Eb=10.416620555390, Ergotropy=10.407796672749, Ratio=0.999153, Variance=8.4845970197e+00,Fluctuation w.r.t erg=2.7987029838e-01,Fluctuation w.r.t EB=2.7963322124e-01
# ω0=4.5, τ=0.531477, Eb=8.671647791040, Ergotropy=8.665796208269, Ratio=0.999325, Variance=7.3147452817e+00,Fluctuation w.r.t erg=3.1209810530e-01,Fluctuation w.r.t EB=3.1188750312e-01
# ω0=5.0, τ=0.481432, Eb=7.187032197043, Ergotropy=7.183346531506, Ratio=0.999487, Variance=6.2417361411e+00,Fluctuation w.r.t erg=3.4779704287e-01,Fluctuation w.r.t EB=3.4761868502e-01
# ω0=5.5, τ=0.441396, Eb=6.057462540539, Ergotropy=6.055019943177, Ratio=0.999597, Variance=5.3789494686e+00,Fluctuation w.r.t erg=3.8303032088e-01,Fluctuation w.r.t EB=3.8287586861e-01
# ω0=6.0, τ=0.411369, Eb=5.213899603452, Ergotropy=5.212156731784, Ratio=0.999666, Variance=4.7078341627e+00,Fluctuation w.r.t erg=4.1628725173e-01,Fluctuation w.r.t EB=4.1614809768e-01
# ω0=6.5, τ=0.381342, Eb=4.483771195008, Ergotropy=4.482562634751, Ratio=0.999730, Variance=4.1068703805e+00,Fluctuation w.r.t erg=4.5209440395e-01,Fluctuation w.r.t EB=4.5197254597e-01
# ω0=7.0, τ=0.351315, Eb=3.847997617379, Ergotropy=3.847186124280, Ratio=0.999789, Variance=3.5683667832e+00,Fluctuation w.r.t erg=4.9101136709e-01,Fluctuation w.r.t EB=4.9090781912e-01
# ω0=7.5, τ=0.331297, Eb=3.393464448071, Ergotropy=3.392855713998, Ratio=0.999821, Variance=3.1751992029e+00,Fluctuation w.r.t erg=5.2519441295e-01,Fluctuation w.r.t EB=5.2510020134e-01
# ω0=8.0, τ=0.311279, Eb=2.992257262946, Ergotropy=2.991809080465, Ratio=0.999850, Variance=2.8218883965e+00,Fluctuation w.r.t erg=5.6148226206e-01,Fluctuation w.r.t EB=5.6139816284e-01
# ω0=8.5, τ=0.291261, Eb=2.636315511636, Ergotropy=2.635992326001, Ratio=0.999877, Variance=2.5035193036e+00,Fluctuation w.r.t erg=6.0024884163e-01,Fluctuation w.r.t EB=6.0017525718e-01
# ω0=9.0, τ=0.281252, Eb=2.402911641002, Ergotropy=2.402640488617, Ratio=0.999887, Variance=2.2925399720e+00,Fluctuation w.r.t erg=6.3018732932e-01,Fluctuation w.r.t EB=6.3011621693e-01
# ω0=9.5, τ=0.261234, Eb=2.114751293663, Ergotropy=2.114562709577, Ratio=0.999911, Variance=2.0288676217e+00,Fluctuation w.r.t erg=6.7360652684e-01,Fluctuation w.r.t EB=6.7354645761e-01
# ω0=10.0, τ=0.251225, Eb=1.930373545736, Ergotropy=1.930218461424, Ratio=0.999920, Variance=1.8587505175e+00,Fluctuation w.r.t erg=7.0632419982e-01,Fluctuation w.r.t EB=7.0626745443e-01
# ω0=10.5, τ=0.241216, Eb=1.763135157363, Ergotropy=1.763008628718, Ratio=0.999928, Variance=1.7033229731e+00,Fluctuation w.r.t erg=7.4027667233e-01,Fluctuation w.r.t EB=7.4022354753e-01
# ω0=11.0, τ=0.221198, Eb=1.542639302185, Ergotropy=1.542556688515, Ratio=0.999946, Variance=1.4966109032e+00,Fluctuation w.r.t erg=7.9307328225e-01,Fluctuation w.r.t EB=7.9303081043e-01
# ω0=11.5, τ=0.211189, Eb=1.407413387291, Ergotropy=1.407347799687, Ratio=0.999953, Variance=1.3690456954e+00,Fluctuation w.r.t erg=8.3139523976e-01,Fluctuation w.r.t EB=8.3135649547e-01
# ω0=12.0, τ=0.211189, Eb=1.346574494564, Ergotropy=1.346509293355, Ratio=0.999952, Variance=1.3115401049e+00,Fluctuation w.r.t erg=8.5051393271e-01,Fluctuation w.r.t EB=8.5047275079e-01
# ω0=12.5, τ=0.201180, Eb=1.230636363551, Ergotropy=1.230585136060, Ratio=0.999958, Variance=1.2013237242e+00,Fluctuation w.r.t erg=8.9067315300e-01,Fluctuation w.r.t EB=8.9063607710e-01
# ω0=13.0, τ=0.191171, Eb=1.123694457952, Ergotropy=1.123654691874, Ratio=0.999965, Variance=1.0992081340e+00,Fluctuation w.r.t erg=9.3305468350e-01,Fluctuation w.r.t EB=9.3302166391e-01
# ω0=13.5, τ=0.181162, Eb=1.024458024372, Ergotropy=1.024427574262, Ratio=0.999970, Variance=1.0040637766e+00,Fluctuation w.r.t erg=9.7813633035e-01,Fluctuation w.r.t EB=9.7810725706e-01
# ω0=14.0, τ=0.181162, Eb=0.985635851420, Ergotropy=0.985605581289, Ratio=0.999969, Variance=9.6679923408e-01,Fluctuation w.r.t erg=9.9761964973e-01,Fluctuation w.r.t EB=9.9758901156e-01
# ω0=14.5, τ=0.171153, Eb=0.899115052701, Ergotropy=0.899092191861, Ratio=0.999975, Variance=8.8340263221e-01,Fluctuation w.r.t erg=1.0453822420e+00,Fluctuation w.r.t EB=1.0453556622e+00
# ω0=15.0, τ=0.161144, Eb=0.817482724767, Ergotropy=0.817465764371, Ratio=0.999979, Variance=8.0446164169e-01,Fluctuation w.r.t erg=1.0971931741e+00,Fluctuation w.r.t EB=1.0971704105e+00

# %%
for i in range(len(ω0_arr2)):
    print(
        f"ω0={ω0_arr2[i]}, "
        f"τ={tau2[i]:.6f}, "
        f"Eb={E_B2[i]:.12f}, "
        f"Ergotropy={E_ergo2[i]:.12f}, "
        f"Ratio={E_ratio2[i]:.6f}, "
        f"Variance={E_var2[i]:.10e},"
        f"Fluctuation w.r.t erg={F_ratio2[i]:.10e},"
        f"Fluctuation w.r.t EB={FE_ratio2[i]:.10e}"
    )
# Out:
# ω0=1.0, τ=1.081973, Eb=31.420878513566, Ergotropy=31.349050137187, Ratio=0.997714, Variance=1.5500931185e+01,Fluctuation w.r.t erg=1.2558984016e-01,Fluctuation w.r.t EB=1.2530274079e-01
# ω0=1.5, τ=1.021919, Eb=28.847325024955, Ergotropy=28.768102132931, Ratio=0.997254, Variance=1.5411770415e+01,Fluctuation w.r.t erg=1.3646304366e-01,Fluctuation w.r.t EB=1.3608827765e-01
# ω0=2.0, τ=0.921829, Eb=24.261588229341, Ergotropy=24.201931844134, Ratio=0.997541, Variance=1.4651051587e+01,Fluctuation w.r.t erg=1.5815552392e-01,Fluctuation w.r.t EB=1.5776663813e-01
# ω0=2.5, τ=0.811730, Eb=19.519046619327, Ergotropy=19.482122562434, Ratio=0.998108, Variance=1.3147465377e+01,Fluctuation w.r.t erg=1.8611644423e-01,Fluctuation w.r.t EB=1.8576436894e-01
# ω0=3.0, τ=0.721649, Eb=15.732277266888, Ergotropy=15.709452870861, Ratio=0.998549, Variance=1.1495997368e+01,Fluctuation w.r.t erg=2.1583022733e-01,Fluctuation w.r.t EB=2.1551710072e-01
# ω0=3.5, τ=0.651586, Eb=12.862579843565, Ergotropy=12.847838017033, Ratio=0.998854, Variance=9.9777422772e+00,Fluctuation w.r.t erg=2.4585898737e-01,Fluctuation w.r.t EB=2.4557720793e-01
# ω0=4.0, τ=0.581523, Eb=10.416620555390, Ergotropy=10.407777389704, Ratio=0.999151, Variance=8.4847782831e+00,Fluctuation w.r.t erg=2.7987380645e-01,Fluctuation w.r.t EB=2.7963620824e-01
# ω0=4.5, τ=0.531477, Eb=8.671647791040, Ergotropy=8.665788685536, Ratio=0.999324, Variance=7.3148257237e+00,Fluctuation w.r.t erg=3.1210009233e-01,Fluctuation w.r.t EB=3.1188921806e-01
# ω0=5.0, τ=0.481432, Eb=7.187032197043, Ergotropy=7.183343849967, Ratio=0.999487, Variance=6.2417683556e+00,Fluctuation w.r.t erg=3.4779807021e-01,Fluctuation w.r.t EB=3.4761958207e-01
# ω0=5.5, τ=0.441396, Eb=6.057462540539, Ergotropy=6.055018873657, Ratio=0.999597, Variance=5.3789637699e+00,Fluctuation w.r.t erg=3.8303089773e-01,Fluctuation w.r.t EB=3.8287637760e-01
# ω0=6.0, τ=0.411369, Eb=5.213899603452, Ergotropy=5.212156232958, Ratio=0.999666, Variance=4.7078415275e+00,Fluctuation w.r.t erg=4.1628761719e-01,Fluctuation w.r.t EB=4.1614842318e-01
# ω0=6.5, τ=0.381342, Eb=4.483771195008, Ergotropy=4.482562413429, Ratio=0.999730, Variance=4.1068739606e+00,Fluctuation w.r.t erg=4.5209462333e-01,Fluctuation w.r.t EB=4.5197274297e-01
# ω0=7.0, τ=0.351315, Eb=3.847997617379, Ergotropy=3.847186031609, Ratio=0.999789, Variance=3.5683684155e+00,Fluctuation w.r.t erg=4.9101149122e-01,Fluctuation w.r.t EB=4.9090793140e-01
# ω0=7.5, τ=0.331297, Eb=3.393464448071, Ergotropy=3.392855665290, Ratio=0.999821, Variance=3.1752001326e+00,Fluctuation w.r.t erg=5.2519449737e-01,Fluctuation w.r.t EB=5.2510027821e-01
# ω0=8.0, τ=0.311279, Eb=2.992257262946, Ergotropy=2.991809055665, Ratio=0.999850, Variance=2.8218889073e+00,Fluctuation w.r.t erg=5.6148231754e-01,Fluctuation w.r.t EB=5.6139821365e-01
# ω0=8.5, τ=0.291261, Eb=2.636315511636, Ergotropy=2.635992313811, Ratio=0.999877, Variance=2.5035195740e+00,Fluctuation w.r.t erg=6.0024887681e-01,Fluctuation w.r.t EB=6.0017528959e-01
# ω0=9.0, τ=0.281252, Eb=2.402911641002, Ergotropy=2.402640480476, Ratio=0.999887, Variance=2.2925401656e+00,Fluctuation w.r.t erg=6.3018735807e-01,Fluctuation w.r.t EB=6.3011624354e-01
# ω0=9.5, τ=0.261234, Eb=2.114751293663, Ergotropy=2.114562705788, Ratio=0.999911, Variance=2.0288677190e+00,Fluctuation w.r.t erg=6.7360654419e-01,Fluctuation w.r.t EB=6.7354647376e-01
# ω0=10.0, τ=0.251225, Eb=1.930373545736, Ergotropy=1.930218458950, Ratio=0.999920, Variance=1.8587505858e+00,Fluctuation w.r.t erg=7.0632421369e-01,Fluctuation w.r.t EB=7.0626746739e-01
# ω0=10.5, τ=0.241216, Eb=1.763135157363, Ergotropy=1.763008627110, Ratio=0.999928, Variance=1.7033230209e+00,Fluctuation w.r.t erg=7.4027668338e-01,Fluctuation w.r.t EB=7.4022355790e-01
# ω0=11.0, τ=0.221198, Eb=1.542639302185, Ergotropy=1.542556687799, Ratio=0.999946, Variance=1.4966109269e+00,Fluctuation w.r.t erg=7.9307328889e-01,Fluctuation w.r.t EB=7.9303081671e-01
# ω0=11.5, τ=0.211189, Eb=1.407413387291, Ergotropy=1.407347799215, Ratio=0.999953, Variance=1.3690457126e+00,Fluctuation w.r.t erg=8.3139524524e-01,Fluctuation w.r.t EB=8.3135650068e-01
# ω0=12.0, τ=0.211189, Eb=1.346574494564, Ergotropy=1.346509292901, Ratio=0.999952, Variance=1.3115401222e+00,Fluctuation w.r.t erg=8.5051393862e-01,Fluctuation w.r.t EB=8.5047275640e-01
# ω0=12.5, τ=0.201180, Eb=1.230636363551, Ergotropy=1.230585135750, Ratio=0.999958, Variance=1.2013237373e+00,Fluctuation w.r.t erg=8.9067315805e-01,Fluctuation w.r.t EB=8.9063608193e-01
# ω0=13.0, τ=0.191171, Eb=1.123694457952, Ergotropy=1.123654691652, Ratio=0.999965, Variance=1.0992081442e+00,Fluctuation w.r.t erg=9.3305468801e-01,Fluctuation w.r.t EB=9.3302166824e-01
# ω0=13.5, τ=0.181162, Eb=1.024458024372, Ergotropy=1.024427574095, Ratio=0.999970, Variance=1.0040637849e+00,Fluctuation w.r.t erg=9.7813633457e-01,Fluctuation w.r.t EB=9.7810726112e-01
# ω0=14.0, τ=0.181162, Eb=0.985635851420, Ergotropy=0.985605581125, Ratio=0.999969, Variance=9.6679924261e-01,Fluctuation w.r.t erg=9.9761965430e-01,Fluctuation w.r.t EB=9.9758901596e-01
# ω0=14.5, τ=0.171153, Eb=0.899115052701, Ergotropy=0.899092191730, Ratio=0.999975, Variance=8.8340263943e-01,Fluctuation w.r.t erg=1.0453822464e+00,Fluctuation w.r.t EB=1.0453556664e+00
# ω0=15.0, τ=0.161144, Eb=0.817482724767, Ergotropy=0.817465764266, Ratio=0.999979, Variance=8.0446164769e-01,Fluctuation w.r.t erg=1.0971931783e+00,Fluctuation w.r.t EB=1.0971704146e+00

# %%
##########################################################
# Relative ergotropy fluctuations vs normalized ergotropy
##########################################################

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

N = 50

E_max_arr1 = ω0_arr1 * N
E_max_arr2 = ω0_arr2 * N

# Numerical data
x1 = E_ergo1 / E_max_arr1
y1 = F_ratio1

x2 = E_ergo2 / E_max_arr2
y2 = F_ratio2

# Domain for theoretical bounds
xb = np.linspace(0.01, 1.0, 400)

# Upper bounds
bound_finite = np.sqrt(1 / xb**2 - 1)
bound_largeN = np.sqrt(1 / xb - 1)

# --------------------------------------------------------
# Figure and axes
# --------------------------------------------------------

fig, ax = plt.subplots(figsize=(14, 6), dpi=500)

# --------------------------------------------------------
# Common normalization
# --------------------------------------------------------

norm = Normalize(
    vmin=min(ω0_arr1.min(), ω0_arr2.min()),
    vmax=max(ω0_arr1.max(), ω0_arr2.max())
)

# --------------------------------------------------------
# Numerical results
# --------------------------------------------------------

sc1 = ax.scatter(
    x1,
    y1,
    c=ω0_arr1,
    cmap='Blues',
    norm=norm,
    marker='o',
    s=45,
    edgecolors='k',
    linewidth=0.3,
    label='Distinguishable battery'
)

sc2 = ax.scatter(
    x2,
    y2,
    c=ω0_arr2,
    cmap='Reds',
    norm=norm,
    marker='s',
    s=45,
    edgecolors='k',
    linewidth=0.3,
    label='Indistinguishable battery'
)

# --------------------------------------------------------
# Theoretical bounds
# --------------------------------------------------------

ax.plot(
    xb,
    bound_finite,
    'r-',
    lw=2,
    label=r'General upper bound: $\sqrt{({\mathcal{E}_b/E_{\max}})^{-2}-1}$'
)

ax.plot(
    xb,
    bound_largeN,
    'g--',
    lw=2,
    label=r'Positive-work upper bound: $\sqrt{({\mathcal{E}_b/E_{\max}})^{-1}-1}$'
)

# --------------------------------------------------------
# Axis limits and labels
# --------------------------------------------------------

ax.set_xlim(-0.02, 1.0)
ax.set_ylim(0, 4)

ax.set_xlabel(
    r'$\mathcal{E}_b/E_{\max}$',
    fontsize=13
)

ax.set_ylabel(
    r'$\sigma_{\mathcal{E}_b}/\langle \mathcal{E}_b\rangle$',
    fontsize=13
)

ax.set_title(
    f"Relative ergotropy fluctuations and theoretical upper bounds of {model} model for N={N}",
    fontsize=11
)

# --------------------------------------------------------
# Colorbar for distinguishable battery
# --------------------------------------------------------

sm1 = ScalarMappable(
    norm=norm,
    cmap='Blues'
)

sm1.set_array([])

cbar1 = fig.colorbar(
    sm1,
    ax=ax,
    pad=0.02
)

cbar1.set_label(
    r'$\omega_B$ — distinguishable',
    fontsize=12
)

cbar1.set_ticks(
    [1, 5, 10, 15]
)

# --------------------------------------------------------
# Colorbar for indistinguishable battery
# --------------------------------------------------------

sm2 = ScalarMappable(
    norm=norm,
    cmap='Reds'
)

sm2.set_array([])

cbar2 = fig.colorbar(
    sm2,
    ax=ax,
    pad=0.10
)

cbar2.set_label(
    r'$\omega_B$ — indistinguishable',
    fontsize=12
)

cbar2.set_ticks(
    [1, 5, 10, 15]
)

# --------------------------------------------------------
# Legend
# --------------------------------------------------------

ax.legend(fontsize=10)

plt.tight_layout()
plt.show()
